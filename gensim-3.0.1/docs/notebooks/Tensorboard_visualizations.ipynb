# %% [markdown]
# # TensorBoard Visualizations
#
#
# In this tutorial, we will learn how to visualize different types of NLP based Embeddings via TensorBoard. TensorBoard is a data visualization framework for visualizing and inspecting the TensorFlow runs and graphs. We will use a built-in Tensorboard visualizer called *Embedding Projector* in this tutorial. It lets you interactively visualize and analyze high-dimensional data like embeddings.

# %% [markdown]
# ## Read Data
#
# For this tutorial, a transformed MovieLens dataset<sup>[1]</sup> is used. You can download the final prepared csv from [here](https://github.com/parulsethi/DocViz/blob/master/movie_plots.csv).

# %%
import gensim
import pandas as pd
import smart_open
import random

# read data
dataframe = pd.read_csv('/Users/Shemelis/10-16-2017-GW-Arlington-Class-Repository-DATA/Machine-Learning-Project/All_Journal_data.csv',index_col='pmid')
# /Users/Shemelis/10-16-2017-GW-Arlington-Class-Repository-DATA/Machine-Learning-Project/All_Journal_data.csv
dataframe=dataframe. sample(n=10, axis=0)
dataframe.head()
# Out:
#           Unnamed: 0  Unnamed: 0.1  \
# pmid
# 29235502       10911          6708
# 29487327        6746          2371
# 29511259        6383          1948
# 29044132       14884         10805
# 29346419       29844          4511
#
#                                                       title  \
# pmid
# 29235502  Stress-induced release of the S100A8/A9 alarmi...
# 29487327  Molecular detection of colistin resistance gen...
# 29511259  Plant-made Salmonella bacteriocins salmocins f...
# 29044132  Enhancement mechanisms of short-time aerobic d...
# 29346419  SAXS analysis of a soluble cytosolic NgBR cons...
#
#                                                    abstract   journal  label
# pmid
# 29235502  Psychological stress is thought to be an impor...   sci_rep      2
# 29487327  Antimicrobial resistance against colistin has ...   sci_rep      2
# 29511259  Salmonella enterica causes an estimated 1 mill...   sci_rep      2
# 29044132  Cocoamidopropyl betaine (CAPB), which is a bio...   sci_rep      2
# 29346419  The Nogo-B receptor (NgBR) is involved in onco...  plos_one      2

# %% [markdown]
# # 1. Visualizing Doc2Vec
# In this part, we will learn about visualizing Doc2Vec Embeddings aka [Paragraph Vectors](https://arxiv.org/abs/1405.4053) via TensorBoard. The input documents for training will be the synopsis of movies, on which Doc2Vec model is trained.
#
# <img src="Tensorboard.png">
#
# The visualizations will be a scatterplot as seen in the above image, where each datapoint is labelled by the movie title and colored by it's corresponding genre. You can also visit this [Projector link](http://projector.tensorflow.org/?config=https://raw.githubusercontent.com/parulsethi/DocViz/master/movie_plot_config.json) which is configured with my embeddings for the above mentioned dataset.
#
#
# ## Preprocess Text

# %% [markdown]
# Below, we define a function to read the training documents, pre-process each document using a simple gensim pre-processing tool (i.e., tokenize text into individual words, remove punctuation, set to lowercase, etc), and return a list of words. Also, to train the model, we'll need to associate a tag/number with each document of the training corpus. In our case, the tag is simply the zero-based line number.

# %%
def read_corpus(documents):
    for i, plot in enumerate(documents):
        yield gensim.models.doc2vec.TaggedDocument(gensim.utils.simple_preprocess(plot, max_len=30), [i])

# %%
train_corpus = list(read_corpus(dataframe.abstract))

# %% [markdown]
# Let's take a look at the training corpus.

# %%
train_corpus[:2]
# Out:
# [TaggedDocument(words=['psychological', 'stress', 'is', 'thought', 'to', 'be', 'an', 'important', 'trigger', 'of', 'cardiovascular', 'events', 'yet', 'the', 'involved', 'pathways', 'and', 'mediators', 'are', 'largely', 'unknown', 'elevated', 'systemic', 'levels', 'of', 'the', 'pro', 'inflammatory', 'alarmin', 'correlate', 'with', 'poor', 'prognosis', 'in', 'coronary', 'artery', 'disease', 'cad', 'patients', 'here', 'we', 'investigated', 'the', 'links', 'between', 'release', 'and', 'parameters', 'of', 'anti', 'inflammatory', 'glucocorticoid', 'secretion', 'in', 'two', 'different', 'cohorts', 'subjected', 'to', 'psychological', 'stress', 'test', 'in', 'the', 'first', 'cohort', 'of', 'cad', 'patients', 'psychological', 'stress', 'induced', 'rapid', 'increase', 'of', 'circulating', 'this', 'rapid', 'response', 'strongly', 'correlated', 'with', 'elevated', 'evening', 'saliva', 'cortisol', 'levels', 'suggesting', 'an', 'association', 'with', 'dysregulated', 'hypothalamic', 'pituitary', 'adrenal', 'hpa', 'axis', 'in', 'the', 'second', 'cohort', 'of', 'cad', 'patients', 'and', 'controls', 'elevated', 'levels', 'were', 'still', 'detectable', 'after', 'stress', 'in', 'of', 'patients', 'and', 'of', 'controls', 'with', 'tendency', 'for', 'higher', 'levels', 'in', 'patients', 'the', 'sustained', 'response', 'was', 'associated', 'with', 'poor', 'rapid', 'cortisol', 'release', 'after', 'stress', 'in', 'patients', 'but', 'not', 'in', 'the', 'control', 'group', 'our', 'findings', 'reveal', 'for', 'the', 'first', 'time', 'that', 'acute', 'psychological', 'stress', 'induces', 'elevated', 'levels', 'of', 'we', 'also', 'provide', 'hypothesis', 'generating', 'evidence', 'that', 'dysregulated', 'cortisol', 'secretion', 'in', 'cad', 'patients', 'might', 'be', 'associated', 'with', 'an', 'exaggerated', 'pro', 'inflammatory', 'response', 'cardiology', 'skane', 'hospital', 'malmo'], tags=[0]),
#  TaggedDocument(words=['antimicrobial', 'resistance', 'against', 'colistin', 'has', 'emerged', 'worldwide', 'and', 'is', 'threatening', 'the', 'efficacy', 'of', 'colistin', 'treatment', 'of', 'multi', 'resistant', 'gram', 'negative', 'bacteria', 'in', 'this', 'study', 'pcrs', 'were', 'used', 'to', 'detect', 'mcr', 'genes', 'mcr', 'mcr', 'mcr', 'in', 'anal', 'and', 'nasal', 'swabs', 'from', 'pigs', 'in', 'nine', 'provinces', 'of', 'china', 'and', 'cloacal', 'and', 'oropharyngeal', 'samples', 'from', 'poultry', 'at', 'live', 'bird', 'markets', 'in', 'provinces', 'the', 'mcr', 'prevalences', 'in', 'pigs', 'and', 'geese', 'were', 'significantly', 'higher', 'than', 'in', 'chickens', 'ducks', 'and', 'pigeons', 'the', 'mcr', 'prevalence', 'in', 'pigs', 'was', 'significantly', 'higher', 'than', 'in', 'chickens', 'ducks', 'geese', 'and', 'pigeons', 'the', 'mcr', 'prevalences', 'in', 'pigs', 'ducks', 'and', 'geese', 'were', 'significantly', 'higher', 'than', 'in', 'chickens', 'and', 'pigeons', 'in', 'total', 'pigs', 'and', 'three', 'chickens', 'were', 'positive', 'for', 'all', 'three', 'mcr', 'genes', 'the', 'prevalences', 'of', 'the', 'mcr', 'were', 'significantly', 'higher', 'in', 'nasal', 'oropharyngeal', 'swabs', 'than', 'in', 'the', 'anal', 'cloacal', 'swabs', 'phylogenetic', 'studies', 'identified', 'new', 'mcr', 'variants', 'and', 'new', 'mcr', 'variants', 'this', 'study', 'demonstrates', 'high', 'prevalences', 'of', 'mcr', 'in', 'pigs', 'and', 'poultry', 'in', 'china', 'and', 'indicates', 'there', 'is', 'need', 'for', 'more', 'thorough', 'surveillance', 'and', 'control', 'programs', 'to', 'prevent', 'further', 'selection', 'of', 'colistin', 'resistance', 'college', 'veterinary', 'medicine', 'auburn', 'auburn'], tags=[1])]

# %% [markdown]
# ## Training the Doc2Vec Model
# We'll instantiate a Doc2Vec model with a vector size with 50 words and iterating over the training corpus 55 times. We set the minimum word count to 2 in order to give higher frequency words more weighting. Model accuracy can be improved by increasing the number of iterations but this generally increases the training time. Small datasets with short documents, like this one, can benefit from more training passes.

# %%
model = gensim.models.doc2vec.Doc2Vec(size=50, min_count=2, iter=55)
model.build_vocab(train_corpus)
model.train(train_corpus, total_examples=model.corpus_count, epochs=model.iter)
# Out:
# /Users/Shemelis/anaconda/lib/python3.6/site-packages/gensim-3.4.0-py3.6-macosx-10.7-x86_64.egg/gensim/models/doc2vec.py:362: UserWarning: The parameter `iter` is deprecated, will be removed in 4.0.0, use `epochs` instead.
#   warnings.warn("The parameter `iter` is deprecated, will be removed in 4.0.0, use `epochs` instead.")
# /Users/Shemelis/anaconda/lib/python3.6/site-packages/gensim-3.4.0-py3.6-macosx-10.7-x86_64.egg/gensim/models/doc2vec.py:366: UserWarning: The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.
#   warnings.warn("The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.")
# 2018-04-22 11:25:37,406 : MainThread : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2018-04-22 11:25:37,408 : MainThread : INFO : collecting all words and their counts
# 2018-04-22 11:25:37,410 : MainThread : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2018-04-22 11:25:37,411 : MainThread : INFO : collected 811 word types and 10 unique tags from a corpus of 10 examples and 1834 words
# 2018-04-22 11:25:37,412 : MainThread : INFO : Loading a fresh vocabulary
# 2018-04-22 11:25:37,415 : MainThread : INFO : min_count=2 retains 274 unique words (33% of original 811, drops 537)
# 2018-04-22 11:25:37,416 : MainThread : INFO : min_count=2 leaves 1297 word corpus (70% of original 1834, drops 537)
# 2018-04-22 11:25:37,420 : MainThread : INFO : deleting the raw counts dictionary of 811 items
# 2018-04-22 11:25:37,421 : MainThread : INFO : sample=0.001 downsamples 87 most-common words
# 2018-04-22 11:25:37,423 : MainThread : INFO : downsampling leaves estimated 825 word corpus (63.7% of prior 1297)
# 2018-04-22 11:25:37,425 : MainThread : INFO : estimated required memory for 274 words and 50 dimensions: 248600 bytes
# 2018-04-22 11:25:37,427 : MainThread : INFO : resetting layer weights
# /Users/Shemelis/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:3: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
#   app.launch_new_instance()
# 2018-04-22 11:25:37,434 : MainThread : INFO : training model with 3 workers on 274 vocabulary and 50 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2018-04-22 11:25:37,439 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,441 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,442 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,443 : MainThread : INFO : EPOCH - 1 : training on 1834 raw words (868 effective words) took 0.0s, 146107 effective words/s
# 2018-04-22 11:25:37,445 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,447 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,449 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,450 : MainThread : INFO : EPOCH - 2 : training on 1834 raw words (841 effective words) took 0.0s, 173676 effective words/s
# 2018-04-22 11:25:37,463 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,466 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,468 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,471 : MainThread : INFO : EPOCH - 3 : training on 1834 raw words (829 effective words) took 0.0s, 71258 effective words/s
# 2018-04-22 11:25:37,479 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,484 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,487 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,489 : MainThread : INFO : EPOCH - 4 : training on 1834 raw words (849 effective words) took 0.0s, 78772 effective words/s
# 2018-04-22 11:25:37,493 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,496 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,497 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,498 : MainThread : INFO : EPOCH - 5 : training on 1834 raw words (843 effective words) took 0.0s, 158473 effective words/s
# 2018-04-22 11:25:37,504 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,507 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,512 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,516 : MainThread : INFO : EPOCH - 6 : training on 1834 raw words (829 effective words) took 0.0s, 69638 effective words/s
# 2018-04-22 11:25:37,520 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,524 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,528 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,534 : MainThread : INFO : EPOCH - 7 : training on 1834 raw words (853 effective words) took 0.0s, 62446 effective words/s
# 2018-04-22 11:25:37,538 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,543 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,546 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,548 : MainThread : INFO : EPOCH - 8 : training on 1834 raw words (831 effective words) took 0.0s, 81700 effective words/s
# 2018-04-22 11:25:37,553 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,555 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,560 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,562 : MainThread : INFO : EPOCH - 9 : training on 1834 raw words (839 effective words) took 0.0s, 87307 effective words/s
# 2018-04-22 11:25:37,568 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,571 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,573 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,576 : MainThread : INFO : EPOCH - 10 : training on 1834 raw words (828 effective words) took 0.0s, 96622 effective words/s
# 2018-04-22 11:25:37,584 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,586 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,588 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,589 : MainThread : INFO : EPOCH - 11 : training on 1834 raw words (809 effective words) took 0.0s, 98501 effective words/s
# 2018-04-22 11:25:37,594 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,598 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,602 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,604 : MainThread : INFO : EPOCH - 12 : training on 1834 raw words (839 effective words) took 0.0s, 83734 effective words/s
# 2018-04-22 11:25:37,611 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,615 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,619 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,622 : MainThread : INFO : EPOCH - 13 : training on 1834 raw words (832 effective words) took 0.0s, 74342 effective words/s
# 2018-04-22 11:25:37,631 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,634 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,637 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,638 : MainThread : INFO : EPOCH - 14 : training on 1834 raw words (820 effective words) took 0.0s, 94434 effective words/s
# 2018-04-22 11:25:37,644 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,646 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,647 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,649 : MainThread : INFO : EPOCH - 15 : training on 1834 raw words (821 effective words) took 0.0s, 162243 effective words/s
# 2018-04-22 11:25:37,659 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,662 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,665 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,669 : MainThread : INFO : EPOCH - 16 : training on 1834 raw words (853 effective words) took 0.0s, 86287 effective words/s
# 2018-04-22 11:25:37,672 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,677 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,680 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,682 : MainThread : INFO : EPOCH - 17 : training on 1834 raw words (820 effective words) took 0.0s, 78112 effective words/s
# 2018-04-22 11:25:37,686 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,688 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,691 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,694 : MainThread : INFO : EPOCH - 18 : training on 1834 raw words (826 effective words) took 0.0s, 97065 effective words/s
# 2018-04-22 11:25:37,700 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,703 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,704 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,707 : MainThread : INFO : EPOCH - 19 : training on 1834 raw words (829 effective words) took 0.0s, 105752 effective words/s
# 2018-04-22 11:25:37,713 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,718 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,720 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,722 : MainThread : INFO : EPOCH - 20 : training on 1834 raw words (828 effective words) took 0.0s, 81561 effective words/s
# 2018-04-22 11:25:37,729 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,732 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,735 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,737 : MainThread : INFO : EPOCH - 21 : training on 1834 raw words (835 effective words) took 0.0s, 99755 effective words/s
# 2018-04-22 11:25:37,740 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,746 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,748 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,750 : MainThread : INFO : EPOCH - 22 : training on 1834 raw words (825 effective words) took 0.0s, 80666 effective words/s
# 2018-04-22 11:25:37,753 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,758 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,761 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,764 : MainThread : INFO : EPOCH - 23 : training on 1834 raw words (857 effective words) took 0.0s, 80681 effective words/s
# 2018-04-22 11:25:37,767 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,770 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,773 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,778 : MainThread : INFO : EPOCH - 24 : training on 1834 raw words (836 effective words) took 0.0s, 76831 effective words/s
# 2018-04-22 11:25:37,783 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,787 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,788 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,789 : MainThread : INFO : EPOCH - 25 : training on 1834 raw words (832 effective words) took 0.0s, 137090 effective words/s
# 2018-04-22 11:25:37,795 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,801 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,802 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,804 : MainThread : INFO : EPOCH - 26 : training on 1834 raw words (832 effective words) took 0.0s, 87629 effective words/s
# 2018-04-22 11:25:37,810 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,812 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,814 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,816 : MainThread : INFO : EPOCH - 27 : training on 1834 raw words (829 effective words) took 0.0s, 86103 effective words/s
# 2018-04-22 11:25:37,820 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,823 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,828 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,830 : MainThread : INFO : EPOCH - 28 : training on 1834 raw words (825 effective words) took 0.0s, 81636 effective words/s
# 2018-04-22 11:25:37,833 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,838 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,839 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,841 : MainThread : INFO : EPOCH - 29 : training on 1834 raw words (843 effective words) took 0.0s, 100881 effective words/s
# 2018-04-22 11:25:37,847 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,851 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,852 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,854 : MainThread : INFO : EPOCH - 30 : training on 1834 raw words (821 effective words) took 0.0s, 113175 effective words/s
# 2018-04-22 11:25:37,857 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,862 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,865 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,866 : MainThread : INFO : EPOCH - 31 : training on 1834 raw words (832 effective words) took 0.0s, 90584 effective words/s
# 2018-04-22 11:25:37,871 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,873 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,875 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,878 : MainThread : INFO : EPOCH - 32 : training on 1834 raw words (845 effective words) took 0.0s, 106678 effective words/s
# 2018-04-22 11:25:37,884 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,886 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,888 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,889 : MainThread : INFO : EPOCH - 33 : training on 1834 raw words (839 effective words) took 0.0s, 129318 effective words/s
# 2018-04-22 11:25:37,894 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,900 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,902 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,904 : MainThread : INFO : EPOCH - 34 : training on 1834 raw words (830 effective words) took 0.0s, 79554 effective words/s
# 2018-04-22 11:25:37,909 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,914 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,915 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,918 : MainThread : INFO : EPOCH - 35 : training on 1834 raw words (839 effective words) took 0.0s, 96405 effective words/s
# 2018-04-22 11:25:37,921 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,925 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,928 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,931 : MainThread : INFO : EPOCH - 36 : training on 1834 raw words (832 effective words) took 0.0s, 85120 effective words/s
# 2018-04-22 11:25:37,935 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,940 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,943 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,947 : MainThread : INFO : EPOCH - 37 : training on 1834 raw words (845 effective words) took 0.0s, 72026 effective words/s
# 2018-04-22 11:25:37,951 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,955 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,956 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,958 : MainThread : INFO : EPOCH - 38 : training on 1834 raw words (848 effective words) took 0.0s, 114042 effective words/s
# 2018-04-22 11:25:37,963 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,968 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,970 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,971 : MainThread : INFO : EPOCH - 39 : training on 1834 raw words (818 effective words) took 0.0s, 99429 effective words/s
# 2018-04-22 11:25:37,974 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,980 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,982 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,983 : MainThread : INFO : EPOCH - 40 : training on 1834 raw words (821 effective words) took 0.0s, 87818 effective words/s
# 2018-04-22 11:25:37,986 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:37,991 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:37,992 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:37,996 : MainThread : INFO : EPOCH - 41 : training on 1834 raw words (863 effective words) took 0.0s, 89053 effective words/s
# 2018-04-22 11:25:37,999 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:38,004 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:38,006 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:38,007 : MainThread : INFO : EPOCH - 42 : training on 1834 raw words (852 effective words) took 0.0s, 109754 effective words/s
# 2018-04-22 11:25:38,012 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:38,016 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:38,018 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:38,019 : MainThread : INFO : EPOCH - 43 : training on 1834 raw words (823 effective words) took 0.0s, 110653 effective words/s
# 2018-04-22 11:25:38,022 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:38,028 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:38,030 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:38,032 : MainThread : INFO : EPOCH - 44 : training on 1834 raw words (852 effective words) took 0.0s, 85712 effective words/s
# 2018-04-22 11:25:38,036 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:38,039 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:38,041 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:38,042 : MainThread : INFO : EPOCH - 45 : training on 1834 raw words (852 effective words) took 0.0s, 141150 effective words/s
# 2018-04-22 11:25:38,050 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:38,055 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:38,056 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:38,057 : MainThread : INFO : EPOCH - 46 : training on 1834 raw words (824 effective words) took 0.0s, 93788 effective words/s
# 2018-04-22 11:25:38,062 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:38,067 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:38,068 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:38,069 : MainThread : INFO : EPOCH - 47 : training on 1834 raw words (818 effective words) took 0.0s, 101829 effective words/s
# 2018-04-22 11:25:38,073 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:38,078 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:38,081 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:38,083 : MainThread : INFO : EPOCH - 48 : training on 1834 raw words (853 effective words) took 0.0s, 82767 effective words/s
# 2018-04-22 11:25:38,086 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:38,089 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:38,091 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:38,094 : MainThread : INFO : EPOCH - 49 : training on 1834 raw words (831 effective words) took 0.0s, 103294 effective words/s
# 2018-04-22 11:25:38,101 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:38,104 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:38,107 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:38,108 : MainThread : INFO : EPOCH - 50 : training on 1834 raw words (828 effective words) took 0.0s, 98058 effective words/s
# 2018-04-22 11:25:38,114 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:38,119 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:38,120 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:38,121 : MainThread : INFO : EPOCH - 51 : training on 1834 raw words (820 effective words) took 0.0s, 112538 effective words/s
# 2018-04-22 11:25:38,124 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:38,131 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:38,133 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:38,135 : MainThread : INFO : EPOCH - 52 : training on 1834 raw words (835 effective words) took 0.0s, 75758 effective words/s
# 2018-04-22 11:25:38,139 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:38,142 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:38,145 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:38,147 : MainThread : INFO : EPOCH - 53 : training on 1834 raw words (826 effective words) took 0.0s, 86439 effective words/s
# 2018-04-22 11:25:38,153 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:38,156 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:38,158 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:38,161 : MainThread : INFO : EPOCH - 54 : training on 1834 raw words (835 effective words) took 0.0s, 102381 effective words/s
# 2018-04-22 11:25:38,165 : MainThread : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-22 11:25:38,172 : MainThread : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-22 11:25:38,173 : MainThread : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-22 11:25:38,176 : MainThread : INFO : EPOCH - 55 : training on 1834 raw words (835 effective words) took 0.0s, 75990 effective words/s
# 2018-04-22 11:25:38,179 : MainThread : INFO : training on a 100870 raw words (45918 effective words) took 0.7s, 61813 effective words/s

# %% [markdown]
# Now, we'll save the document embedding vectors per doctag.

# %%
model.save_word2vec_format('doc_tensor.w2v', doctag_vec=True, word_vec=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-d36d30f54c5b> in <module>()
# ----> 1 model.save_word2vec_format('doc_tensor.w2v', doctag_vec=True, word_vec=False)
#
# AttributeError: 'LdaModel' object has no attribute 'save_word2vec_format'

# %% [markdown]
# ## Prepare the Input files for Tensorboard

# %% [markdown]
# Tensorboard takes two Input files. One containing the embedding vectors and the other containing relevant metadata. We'll use a gensim script to directly convert the embedding file saved in word2vec format above to the tsv format required in Tensorboard.

# %%
# %run ../../gensim/scripts/word2vec2tensor.py -i doc_tensor.w2v -o abstract_plot
# Out:
# 2018-04-22 11:26:11,493 : MainThread : INFO : running ../../gensim/scripts/word2vec2tensor.py -i doc_tensor.w2v -o abstract_plot
# 2018-04-22 11:26:11,496 : MainThread : INFO : loading projection weights from doc_tensor.w2v
# 2018-04-22 11:26:11,500 : MainThread : INFO : loaded (10, 50) matrix from doc_tensor.w2v
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/Shemelis/10-16-2017-GW-Arlington-Class-Repository-DATA/Machine-Learning-Project/gensim-3.0.1/gensim/scripts/word2vec2tensor.py in <module>()
#      75     args = parser.parse_args()
#      76
# ---> 77     word2vec2tensor(args.input, args.output, args.binary)
#      78
#      79     logger.info("finished running %s", os.path.basename(sys.argv[0]))
#
# /Users/Shemelis/10-16-2017-GW-Arlington-Class-Repository-DATA/Machine-Learning-Project/gensim-3.0.1/gensim/scripts/word2vec2tensor.py in word2vec2tensor(word2vec_model_path, tensor_filename, binary)
#      56         with open(outfiletsvmeta, 'w+') as file_metadata:
#      57             for word in model.index2word:
# ---> 58                 file_metadata.write(gensim.utils.to_utf8(word) + gensim.utils.to_utf8('\n'))
#      59                 vector_row = '\t'.join(str(x) for x in model[word])
#      60                 file_vector.write(vector_row + '\n')
#
# TypeError: write() argument must be str, not bytes

# %% [markdown]
# The script above generates two files, `movie_plot_tensor.tsv` which contain the embedding vectors and `movie_plot_metadata.tsv`  containing doctags. But, these doctags are simply the unique index values and hence are not really useful to interpret what the document was while visualizing. So, we will overwrite `movie_plot_metadata.tsv` to have a custom metadata file with two columns. The first column will be for the movie titles and the second for their corresponding genres.

# %%
with open('movie_plot_metadata.tsv','w') as w:
    w.write('Titles\tGenres\n')
    for i,j in zip(dataframe.title, dataframe.label):
        w.write("%s\t%s\n" % (i,j))

# %% [markdown]
# Now you can go to http://projector.tensorflow.org/ and upload the two files by clicking on *Load data* in the left panel.
#
# For demo purposes I have uploaded the Doc2Vec embeddings generated from the model trained above [here](https://github.com/parulsethi/DocViz). You can access the Embedding projector configured with these uploaded embeddings at this [link](http://projector.tensorflow.org/?config=https://raw.githubusercontent.com/parulsethi/DocViz/master/movie_plot_config.json).

# %% [markdown]
# # Using Tensorboard

# %% [markdown]
# For the visualization purpose, the multi-dimensional embeddings that we get from the Doc2Vec model above, needs to be  downsized to 2 or 3 dimensions. So that we basically end up with a new 2d or 3d embedding which tries to preserve information from the original multi-dimensional embedding. As these vectors are reduced to a much smaller dimension, the exact cosine/euclidean distances between them are not preserved, but rather relative, and hence as you’ll see below the nearest similarity results may change.
#
# TensorBoard has two popular dimensionality reduction methods for visualizing the embeddings and also provides a custom method based on text searches:
#
# - **Principal Component Analysis**: PCA aims at exploring the global structure in data, and could end up losing the local similarities between neighbours. It maximizes the total variance in the lower dimensional subspace and hence, often preserves the larger pairwise distances better than the smaller ones. See an intuition behind it in this nicely explained [answer](https://stats.stackexchange.com/questions/176672/what-is-meant-by-pca-preserving-only-large-pairwise-distances) on stackexchange.
#
#
# - **T-SNE**: The idea of T-SNE is to place the local neighbours close to each other, and almost completely ignoring the global structure. It is useful for exploring local neighborhoods and finding local clusters. But the global trends are not represented accurately and the separation between different groups is often not preserved (see the t-sne plots of our data below which testify the same).
#
#
# - **Custom Projections**: This is a custom bethod based on the text searches you define for different directions. It could be useful for finding meaningful directions in the vector space, for example, female to male, currency to country etc.
#
# You can refer to this [doc](https://www.tensorflow.org/get_started/embedding_viz) for instructions on how to use and navigate through different panels available in TensorBoard.

# %% [markdown]
# ## Visualize using PCA
#
# The Embedding Projector computes the top 10 principal components. The menu at the left panel lets you project those components onto any combination of two or three.
# <img src="pca.png">
# The above plot was made using the first two principal components with total variance covered being 36.5%.

# %% [markdown]
# ## Visualize using T-SNE
#
# Data is visualized by animating through every iteration of the t-sne algorithm. The t-sne menu at the left lets you adjust the value of it's two hyperparameters. The first one is **Perplexity**, which is basically a measure of information. It may be viewed as a knob that sets the number of effective nearest neighbors<sup>[2]</sup>. The second one is **learning rate** that defines how quickly an algorithm learns on encountering new examples/data points.
#
# <img src="tsne.png">
#
# The above plot was generated with perplexity 8, learning rate 10 and iteration 500. Though the results could vary on successive runs, and you may not get the exact plot as above with same hyperparameter settings. But some small clusters will start forming as above, with different orientations.

# %% [markdown]
# # 2. Visualizing LDA
#
# In this part, we will see how to visualize LDA in Tensorboard. We will be using the Document-topic distribution as the embedding vector of a document. Basically, we treat topics as the dimensions and the value in each dimension represents the topic proportion of that topic in the document.
#
# ## Preprocess Text
#
# We use the journal abstract as our documents in corpus and remove rare words and common words based on their document frequency. Below we remove words that appear in less than 2 documents or in more than 30% of the documents.

# %%
import pandas as pd
import re
from gensim.parsing.preprocessing import remove_stopwords, strip_punctuation
from gensim.models import ldamodel
from gensim.corpora.dictionary import Dictionary

# read data
# /Users/Shemelis/10-16-2017-GW-Arlington-Class-Repository-DATA/Machine-Learning-Project/All_Journal_data.csv

dataframe = pd.read_csv('/Users/Shemelis/10-16-2017-GW-Arlington-Class-Repository-DATA/Machine-Learning-Project/All_Journal_data.csv')

# remove stopwords and punctuations
def preprocess(row):
    return strip_punctuation(remove_stopwords(row.lower()))
    
dataframe['Plots'] = dataframe['abstract'].apply(preprocess)

# Convert data to required input format by LDA
texts = []
for line in dataframe.abstract:
    lowered = line.lower()
    words = re.findall(r'\w+', lowered, flags = re.UNICODE )
    texts.append(words)
# Create a dictionary representation of the documents.
dictionary = Dictionary(texts)

# Filter out words that occur less than 2 documents, or more than 30% of the documents.
dictionary.filter_extremes(no_below=2, no_above=0.3)
# Bag-of-words representation of the documents.
corpus = [dictionary.doc2bow(text) for text in texts]
# Out:
# 2018-04-22 11:35:34,320 : MainThread : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2018-04-22 11:35:36,718 : MainThread : INFO : adding document #10000 to Dictionary(55774 unique tokens: ['2', 'a', 'aggregation', 'als', 'also']...)
# 2018-04-22 11:35:38,550 : MainThread : INFO : adding document #20000 to Dictionary(81265 unique tokens: ['2', 'a', 'aggregation', 'als', 'also']...)
# 2018-04-22 11:35:40,480 : MainThread : INFO : adding document #30000 to Dictionary(103483 unique tokens: ['2', 'a', 'aggregation', 'als', 'also']...)
# 2018-04-22 11:35:43,443 : MainThread : INFO : adding document #40000 to Dictionary(127570 unique tokens: ['2', 'a', 'aggregation', 'als', 'also']...)
# 2018-04-22 11:35:45,604 : MainThread : INFO : adding document #50000 to Dictionary(146454 unique tokens: ['2', 'a', 'aggregation', 'als', 'also']...)
# 2018-04-22 11:35:48,017 : MainThread : INFO : adding document #60000 to Dictionary(169468 unique tokens: ['2', 'a', 'aggregation', 'als', 'also']...)
# 2018-04-22 11:35:49,649 : MainThread : INFO : built Dictionary(182362 unique tokens: ['2', 'a', 'aggregation', 'als', 'also']...) from 66620 documents (total 14211422 corpus positions)
# 2018-04-22 11:35:49,919 : MainThread : INFO : discarding 96456 tokens: [('a', 62652), ('and', 66361), ('as', 36749), ('by', 45690), ('have', 20943), ('here', 26401), ('in', 65125), ('of', 66459), ('our', 22018), ('that', 54788)]...
# 2018-04-22 11:35:49,920 : MainThread : INFO : keeping 85906 tokens which were in no less than 2 and no more than 19986 (=30.0%) documents
# 2018-04-22 11:35:50,061 : MainThread : INFO : resulting dictionary: Dictionary(85906 unique tokens: ['2', 'aggregation', 'als', 'also', 'amyotrophic']...)

# %% [markdown]
# ## Train LDA Model

# %%
# Set training parameters.
num_topics = 6
chunksize = 2000
passes = 5 #another name of epoch
iterations = 20
eval_every = None

# Train model
model = ldamodel.LdaModel(corpus=corpus, id2word=dictionary, chunksize=chunksize, alpha='auto', eta='auto', iterations=iterations, num_topics=num_topics, passes=passes, eval_every=eval_every)
# Out:
# 2018-04-22 12:28:41,770 : MainThread : INFO : using autotuned alpha, starting with [0.16666667, 0.16666667, 0.16666667, 0.16666667, 0.16666667, 0.16666667]
# 2018-04-22 12:28:41,791 : MainThread : INFO : using serial LDA version on this node
# 2018-04-22 12:28:41,848 : MainThread : INFO : running online (multi-pass) LDA training, 6 topics, 5 passes over the supplied corpus of 66620 documents, updating model once every 2000 documents, evaluating perplexity every 0 documents, iterating 20x with a convergence threshold of 0.001000
# 2018-04-22 12:28:41,850 : MainThread : INFO : PROGRESS: pass 0, at document #2000/66620
# 2018-04-22 12:28:42,607 : MainThread : INFO : optimized alpha [0.30347776, 0.30538231, 0.3038584, 0.30899113, 0.3063333, 0.30563092]
# 2018-04-22 12:28:42,611 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:28:42,659 : MainThread : INFO : topic #0 (0.303): 0.008*"cell" + 0.005*"cells" + 0.004*"protein" + 0.004*"can" + 0.004*"cancer" + 0.003*"molecular" + 0.003*"their" + 0.003*"1" + 0.003*"into" + 0.003*"human"
# 2018-04-22 12:28:42,662 : MainThread : INFO : topic #2 (0.304): 0.007*"cells" + 0.005*"cell" + 0.004*"protein" + 0.003*"their" + 0.003*"biology" + 0.003*"dna" + 0.003*"molecular" + 0.003*"has" + 0.003*"can" + 0.003*"gene"
# 2018-04-22 12:28:42,664 : MainThread : INFO : topic #5 (0.306): 0.006*"cell" + 0.005*"cells" + 0.004*"can" + 0.003*"1" + 0.003*"cancer" + 0.003*"biology" + 0.003*"human" + 0.003*"protein" + 0.003*"dna" + 0.003*"show"
# 2018-04-22 12:28:42,667 : MainThread : INFO : topic #4 (0.306): 0.006*"cell" + 0.005*"cancer" + 0.005*"cells" + 0.004*"human" + 0.004*"molecular" + 0.003*"can" + 0.003*"dna" + 0.003*"their" + 0.003*"biology" + 0.003*"gene"
# 2018-04-22 12:28:42,670 : MainThread : INFO : topic #3 (0.309): 0.005*"cell" + 0.004*"cells" + 0.004*"molecular" + 0.003*"biology" + 0.003*"can" + 0.003*"human" + 0.003*"2" + 0.003*"protein" + 0.003*"new" + 0.003*"into"
# 2018-04-22 12:28:42,673 : MainThread : INFO : topic diff=6.724268, rho=1.000000
# 2018-04-22 12:28:42,737 : MainThread : INFO : PROGRESS: pass 0, at document #4000/66620
# 2018-04-22 12:28:43,562 : MainThread : INFO : optimized alpha [0.44495097, 0.45500898, 0.46038333, 0.46206346, 0.45628655, 0.45883459]
# 2018-04-22 12:28:43,567 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:28:43,609 : MainThread : INFO : topic #0 (0.445): 0.008*"cell" + 0.006*"cells" + 0.004*"1" + 0.004*"protein" + 0.003*"cancer" + 0.003*"can" + 0.003*"genome" + 0.003*"new" + 0.003*"associated" + 0.003*"human"
# 2018-04-22 12:28:43,611 : MainThread : INFO : topic #1 (0.455): 0.006*"cells" + 0.004*"cell" + 0.003*"high" + 0.003*"show" + 0.003*"into" + 0.003*"their" + 0.003*"during" + 0.003*"1" + 0.003*"has" + 0.003*"but"
# 2018-04-22 12:28:43,614 : MainThread : INFO : topic #5 (0.459): 0.005*"cells" + 0.005*"cell" + 0.004*"can" + 0.004*"1" + 0.003*"show" + 0.003*"but" + 0.003*"associated" + 0.003*"human" + 0.003*"between" + 0.003*"dna"
# 2018-04-22 12:28:43,616 : MainThread : INFO : topic #2 (0.460): 0.006*"cells" + 0.004*"cell" + 0.003*"has" + 0.003*"their" + 0.003*"gene" + 0.003*"show" + 0.003*"high" + 0.003*"dna" + 0.003*"than" + 0.003*"protein"
# 2018-04-22 12:28:43,619 : MainThread : INFO : topic #3 (0.462): 0.004*"2" + 0.003*"can" + 0.003*"1" + 0.003*"new" + 0.003*"molecular" + 0.003*"cells" + 0.003*"show" + 0.003*"cell" + 0.003*"been" + 0.003*"complex"
# 2018-04-22 12:28:43,622 : MainThread : INFO : topic diff=15.664952, rho=0.707107
# 2018-04-22 12:28:43,685 : MainThread : INFO : PROGRESS: pass 0, at document #6000/66620
# 2018-04-22 12:28:44,471 : MainThread : INFO : optimized alpha [0.51551342, 0.4749507, 0.49592727, 0.52354771, 0.53822541, 0.53765041]
# 2018-04-22 12:28:44,477 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:28:44,522 : MainThread : INFO : topic #1 (0.475): 0.005*"cells" + 0.004*"high" + 0.004*"quantum" + 0.003*"their" + 0.003*"has" + 0.003*"cell" + 0.003*"show" + 0.003*"during" + 0.003*"into" + 0.003*"1"
# 2018-04-22 12:28:44,525 : MainThread : INFO : topic #2 (0.496): 0.005*"cells" + 0.003*"cell" + 0.003*"than" + 0.003*"has" + 0.003*"their" + 0.003*"high" + 0.003*"gene" + 0.003*"0" + 0.003*"2" + 0.003*"1"
# 2018-04-22 12:28:44,528 : MainThread : INFO : topic #3 (0.524): 0.008*"0" + 0.006*"2" + 0.005*"1" + 0.004*"than" + 0.003*"can" + 0.003*"per" + 0.003*"been" + 0.003*"95" + 0.003*"3" + 0.003*"has"
# 2018-04-22 12:28:44,532 : MainThread : INFO : topic #5 (0.538): 0.009*"0" + 0.008*"1" + 0.006*"patients" + 0.004*"group" + 0.004*"p" + 0.004*"ci" + 0.004*"placebo" + 0.004*"3" + 0.003*"between" + 0.003*"5"
# 2018-04-22 12:28:44,535 : MainThread : INFO : topic #4 (0.538): 0.012*"patients" + 0.007*"0" + 0.007*"group" + 0.006*"cancer" + 0.005*"cells" + 0.005*"2" + 0.005*"cell" + 0.005*"1" + 0.004*"human" + 0.004*"3"
# 2018-04-22 12:28:44,539 : MainThread : INFO : topic diff=4.922027, rho=0.577350
# 2018-04-22 12:28:44,601 : MainThread : INFO : PROGRESS: pass 0, at document #8000/66620
# 2018-04-22 12:28:45,756 : MainThread : INFO : optimized alpha [0.55376697, 0.47110537, 0.5517894, 0.37802452, 0.31224549, 0.28463224]
# 2018-04-22 12:28:45,762 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:28:45,822 : MainThread : INFO : topic #5 (0.285): 0.007*"0" + 0.007*"1" + 0.005*"patients" + 0.003*"data" + 0.003*"between" + 0.003*"group" + 0.003*"3" + 0.003*"p" + 0.003*"can" + 0.003*"than"
# 2018-04-22 12:28:45,827 : MainThread : INFO : topic #4 (0.312): 0.010*"patients" + 0.009*"cancer" + 0.006*"cells" + 0.006*"group" + 0.006*"0" + 0.005*"cell" + 0.005*"1" + 0.004*"2" + 0.004*"human" + 0.003*"therapy"
# 2018-04-22 12:28:45,833 : MainThread : INFO : topic #1 (0.471): 0.004*"cells" + 0.004*"rna" + 0.003*"show" + 0.003*"their" + 0.003*"cell" + 0.003*"can" + 0.003*"during" + 0.003*"but" + 0.003*"its" + 0.003*"has"
# 2018-04-22 12:28:45,839 : MainThread : INFO : topic #2 (0.552): 0.005*"cells" + 0.004*"gene" + 0.004*"cell" + 0.004*"expression" + 0.004*"protein" + 0.004*"dna" + 0.003*"their" + 0.003*"show" + 0.003*"its" + 0.003*"has"
# 2018-04-22 12:28:45,844 : MainThread : INFO : topic #0 (0.554): 0.009*"cell" + 0.008*"cells" + 0.006*"dna" + 0.005*"protein" + 0.005*"1" + 0.004*"binding" + 0.003*"rna" + 0.003*"cancer" + 0.003*"complex" + 0.003*"human"
# 2018-04-22 12:28:45,848 : MainThread : INFO : topic diff=3.665346, rho=0.500000
# 2018-04-22 12:28:45,936 : MainThread : INFO : PROGRESS: pass 0, at document #10000/66620
# 2018-04-22 12:28:46,981 : MainThread : INFO : optimized alpha [0.41764686, 0.44363263, 0.48270756, 0.3409903, 0.2298919, 0.25262234]
# 2018-04-22 12:28:46,988 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:28:47,054 : MainThread : INFO : topic #4 (0.230): 0.009*"cancer" + 0.009*"patients" + 0.007*"cells" + 0.005*"cell" + 0.004*"1" + 0.004*"0" + 0.004*"group" + 0.004*"2" + 0.004*"human" + 0.004*"treatment"
# 2018-04-22 12:28:47,058 : MainThread : INFO : topic #5 (0.253): 0.005*"1" + 0.004*"0" + 0.004*"between" + 0.004*"species" + 0.003*"data" + 0.003*"than" + 0.003*"more" + 0.003*"but" + 0.003*"can" + 0.003*"their"
# 2018-04-22 12:28:47,064 : MainThread : INFO : topic #0 (0.418): 0.009*"cell" + 0.009*"cells" + 0.006*"protein" + 0.005*"dna" + 0.005*"1" + 0.004*"binding" + 0.003*"signaling" + 0.003*"human" + 0.003*"complex" + 0.003*"rna"
# 2018-04-22 12:28:47,071 : MainThread : INFO : topic #1 (0.444): 0.004*"cells" + 0.004*"show" + 0.004*"can" + 0.004*"their" + 0.004*"between" + 0.003*"cell" + 0.003*"into" + 0.003*"but" + 0.003*"during" + 0.003*"has"
# 2018-04-22 12:28:47,076 : MainThread : INFO : topic #2 (0.483): 0.005*"gene" + 0.004*"cells" + 0.004*"protein" + 0.004*"cell" + 0.004*"expression" + 0.003*"their" + 0.003*"show" + 0.003*"genes" + 0.003*"binding" + 0.003*"its"
# 2018-04-22 12:28:47,082 : MainThread : INFO : topic diff=3.285265, rho=0.447214
# 2018-04-22 12:28:47,174 : MainThread : INFO : PROGRESS: pass 0, at document #12000/66620
# 2018-04-22 12:28:48,127 : MainThread : INFO : optimized alpha [0.35037372, 0.37338921, 0.39688429, 0.29180771, 0.19283238, 0.21689096]
# 2018-04-22 12:28:48,132 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:28:48,178 : MainThread : INFO : topic #4 (0.193): 0.009*"cancer" + 0.008*"cells" + 0.007*"patients" + 0.006*"cell" + 0.005*"tumor" + 0.005*"t" + 0.004*"1" + 0.004*"treatment" + 0.004*"human" + 0.004*"expression"
# 2018-04-22 12:28:48,180 : MainThread : INFO : topic #5 (0.217): 0.004*"species" + 0.004*"1" + 0.004*"between" + 0.003*"more" + 0.003*"than" + 0.003*"data" + 0.003*"can" + 0.003*"social" + 0.003*"but" + 0.003*"0"
# 2018-04-22 12:28:48,183 : MainThread : INFO : topic #0 (0.350): 0.010*"cells" + 0.010*"cell" + 0.007*"protein" + 0.005*"dna" + 0.005*"1" + 0.004*"binding" + 0.004*"signaling" + 0.003*"mice" + 0.003*"expression" + 0.003*"human"
# 2018-04-22 12:28:48,186 : MainThread : INFO : topic #1 (0.373): 0.004*"can" + 0.004*"show" + 0.004*"between" + 0.003*"their" + 0.003*"cells" + 0.003*"cell" + 0.003*"neurons" + 0.003*"but" + 0.003*"model" + 0.003*"such"
# 2018-04-22 12:28:48,188 : MainThread : INFO : topic #2 (0.397): 0.005*"protein" + 0.005*"gene" + 0.004*"cell" + 0.004*"cells" + 0.004*"expression" + 0.004*"binding" + 0.003*"genes" + 0.003*"show" + 0.003*"2" + 0.003*"their"
# 2018-04-22 12:28:48,192 : MainThread : INFO : topic diff=2.557212, rho=0.408248
# 2018-04-22 12:28:48,296 : MainThread : INFO : PROGRESS: pass 0, at document #14000/66620
# 2018-04-22 12:28:49,282 : MainThread : INFO : optimized alpha [0.30106536, 0.32446063, 0.34017929, 0.25698739, 0.16665195, 0.1971236]
# 2018-04-22 12:28:49,288 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:28:49,333 : MainThread : INFO : topic #4 (0.167): 0.010*"cancer" + 0.009*"cells" + 0.007*"cell" + 0.006*"patients" + 0.006*"tumor" + 0.005*"t" + 0.004*"human" + 0.004*"treatment" + 0.004*"1" + 0.004*"expression"
# 2018-04-22 12:28:49,335 : MainThread : INFO : topic #5 (0.197): 0.004*"species" + 0.004*"between" + 0.003*"more" + 0.003*"data" + 0.003*"than" + 0.003*"their" + 0.003*"social" + 0.003*"can" + 0.003*"1" + 0.003*"but"
# 2018-04-22 12:28:49,338 : MainThread : INFO : topic #0 (0.301): 0.010*"cells" + 0.010*"cell" + 0.007*"protein" + 0.005*"dna" + 0.005*"1" + 0.004*"binding" + 0.004*"signaling" + 0.004*"expression" + 0.004*"mice" + 0.003*"human"
# 2018-04-22 12:28:49,341 : MainThread : INFO : topic #1 (0.324): 0.004*"can" + 0.004*"show" + 0.004*"between" + 0.003*"neurons" + 0.003*"their" + 0.003*"cell" + 0.003*"such" + 0.003*"cells" + 0.003*"but" + 0.003*"model"
# 2018-04-22 12:28:49,343 : MainThread : INFO : topic #2 (0.340): 0.005*"protein" + 0.005*"gene" + 0.004*"cell" + 0.004*"binding" + 0.004*"expression" + 0.004*"cells" + 0.004*"2" + 0.003*"genes" + 0.003*"proteins" + 0.003*"membrane"
# 2018-04-22 12:28:49,346 : MainThread : INFO : topic diff=2.179360, rho=0.377964
# 2018-04-22 12:28:49,434 : MainThread : INFO : PROGRESS: pass 0, at document #16000/66620
# 2018-04-22 12:28:50,372 : MainThread : INFO : optimized alpha [0.28303024, 0.2991392, 0.29696199, 0.2288789, 0.15329802, 0.17319901]
# 2018-04-22 12:28:50,377 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:28:50,423 : MainThread : INFO : topic #4 (0.153): 0.011*"cancer" + 0.010*"cells" + 0.008*"cell" + 0.007*"tumor" + 0.006*"t" + 0.006*"patients" + 0.005*"expression" + 0.004*"human" + 0.004*"treatment" + 0.004*"1"
# 2018-04-22 12:28:50,425 : MainThread : INFO : topic #5 (0.173): 0.004*"species" + 0.004*"between" + 0.003*"data" + 0.003*"than" + 0.003*"their" + 0.003*"more" + 0.003*"can" + 0.003*"climate" + 0.003*"but" + 0.003*"social"
# 2018-04-22 12:28:50,427 : MainThread : INFO : topic #0 (0.283): 0.012*"cell" + 0.012*"cells" + 0.007*"protein" + 0.005*"1" + 0.005*"signaling" + 0.005*"dna" + 0.004*"binding" + 0.004*"expression" + 0.003*"mice" + 0.003*"show"
# 2018-04-22 12:28:50,429 : MainThread : INFO : topic #2 (0.297): 0.005*"protein" + 0.005*"cell" + 0.005*"gene" + 0.004*"binding" + 0.004*"expression" + 0.004*"membrane" + 0.004*"genes" + 0.004*"proteins" + 0.004*"cells" + 0.003*"2"
# 2018-04-22 12:28:50,432 : MainThread : INFO : topic #1 (0.299): 0.004*"can" + 0.004*"show" + 0.004*"between" + 0.004*"their" + 0.004*"cell" + 0.003*"neurons" + 0.003*"such" + 0.003*"cells" + 0.003*"but" + 0.003*"model"
# 2018-04-22 12:28:50,435 : MainThread : INFO : topic diff=1.846316, rho=0.353553
# 2018-04-22 12:28:50,520 : MainThread : INFO : PROGRESS: pass 0, at document #18000/66620
# 2018-04-22 12:28:51,347 : MainThread : INFO : optimized alpha [0.24888656, 0.28202981, 0.24875543, 0.22253849, 0.14275487, 0.15582578]
# 2018-04-22 12:28:51,353 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:28:51,403 : MainThread : INFO : topic #4 (0.143): 0.012*"cancer" + 0.011*"cells" + 0.008*"tumor" + 0.008*"cell" + 0.006*"t" + 0.006*"patients" + 0.005*"expression" + 0.004*"human" + 0.004*"treatment" + 0.004*"1"
# 2018-04-22 12:28:51,404 : MainThread : INFO : topic #5 (0.156): 0.004*"species" + 0.004*"data" + 0.004*"between" + 0.003*"their" + 0.003*"than" + 0.003*"can" + 0.003*"but" + 0.003*"more" + 0.003*"climate" + 0.003*"show"
# 2018-04-22 12:28:51,407 : MainThread : INFO : topic #2 (0.249): 0.006*"protein" + 0.005*"gene" + 0.005*"cell" + 0.004*"binding" + 0.004*"membrane" + 0.004*"expression" + 0.004*"show" + 0.004*"genes" + 0.004*"proteins" + 0.003*"2"
# 2018-04-22 12:28:51,409 : MainThread : INFO : topic #0 (0.249): 0.012*"cell" + 0.012*"cells" + 0.007*"protein" + 0.005*"dna" + 0.005*"1" + 0.005*"signaling" + 0.004*"show" + 0.004*"binding" + 0.004*"expression" + 0.003*"mice"
# 2018-04-22 12:28:51,412 : MainThread : INFO : topic #1 (0.282): 0.005*"can" + 0.004*"show" + 0.004*"quantum" + 0.004*"between" + 0.003*"their" + 0.003*"neurons" + 0.003*"such" + 0.003*"cell" + 0.003*"single" + 0.003*"state"
# 2018-04-22 12:28:51,415 : MainThread : INFO : topic diff=1.635471, rho=0.333333
# 2018-04-22 12:28:51,502 : MainThread : INFO : PROGRESS: pass 0, at document #20000/66620
# 2018-04-22 12:28:52,268 : MainThread : INFO : optimized alpha [0.22165893, 0.26228878, 0.21401222, 0.21857671, 0.13325875, 0.14034846]
# 2018-04-22 12:28:52,274 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:28:52,321 : MainThread : INFO : topic #4 (0.133): 0.013*"cancer" + 0.012*"cells" + 0.008*"cell" + 0.006*"tumor" + 0.006*"t" + 0.005*"expression" + 0.005*"patients" + 0.005*"human" + 0.004*"treatment" + 0.004*"mutations"
# 2018-04-22 12:28:52,323 : MainThread : INFO : topic #5 (0.140): 0.004*"species" + 0.004*"data" + 0.004*"between" + 0.004*"climate" + 0.003*"show" + 0.003*"their" + 0.003*"than" + 0.003*"can" + 0.003*"but" + 0.003*"more"
# 2018-04-22 12:28:52,325 : MainThread : INFO : topic #3 (0.219): 0.005*"high" + 0.004*"materials" + 0.004*"1" + 0.004*"2" + 0.004*"can" + 0.004*"energy" + 0.003*"surface" + 0.003*"chemistry" + 0.003*"carbon" + 0.003*"chemical"
# 2018-04-22 12:28:52,327 : MainThread : INFO : topic #0 (0.222): 0.012*"cell" + 0.012*"cells" + 0.007*"protein" + 0.005*"show" + 0.005*"dna" + 0.005*"1" + 0.004*"expression" + 0.004*"signaling" + 0.004*"binding" + 0.004*"mice"
# 2018-04-22 12:28:52,330 : MainThread : INFO : topic #1 (0.262): 0.005*"can" + 0.005*"quantum" + 0.004*"show" + 0.004*"between" + 0.004*"their" + 0.003*"such" + 0.003*"single" + 0.003*"neurons" + 0.003*"demonstrate" + 0.003*"state"
# 2018-04-22 12:28:52,334 : MainThread : INFO : topic diff=1.472135, rho=0.316228
# 2018-04-22 12:28:52,417 : MainThread : INFO : PROGRESS: pass 0, at document #22000/66620
# 2018-04-22 12:28:53,173 : MainThread : INFO : optimized alpha [0.1981401, 0.24831402, 0.18846175, 0.21362363, 0.12481543, 0.13105835]
# 2018-04-22 12:28:53,179 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:28:53,227 : MainThread : INFO : topic #4 (0.125): 0.014*"cancer" + 0.012*"cells" + 0.009*"cell" + 0.006*"t" + 0.006*"expression" + 0.005*"tumour" + 0.005*"patients" + 0.005*"tumor" + 0.004*"human" + 0.004*"treatment"
# 2018-04-22 12:28:53,229 : MainThread : INFO : topic #5 (0.131): 0.004*"species" + 0.004*"data" + 0.004*"show" + 0.004*"between" + 0.004*"climate" + 0.003*"than" + 0.003*"their" + 0.003*"but" + 0.003*"can" + 0.003*"more"
# 2018-04-22 12:28:53,231 : MainThread : INFO : topic #0 (0.198): 0.012*"cells" + 0.012*"cell" + 0.007*"protein" + 0.005*"show" + 0.005*"dna" + 0.005*"1" + 0.004*"expression" + 0.004*"activation" + 0.004*"binding" + 0.004*"mice"
# 2018-04-22 12:28:53,233 : MainThread : INFO : topic #3 (0.214): 0.005*"materials" + 0.005*"high" + 0.005*"1" + 0.004*"can" + 0.004*"2" + 0.004*"energy" + 0.003*"surface" + 0.003*"metal" + 0.003*"chemistry" + 0.003*"chemical"
# 2018-04-22 12:28:53,236 : MainThread : INFO : topic #1 (0.248): 0.006*"quantum" + 0.005*"can" + 0.004*"show" + 0.004*"such" + 0.003*"between" + 0.003*"single" + 0.003*"their" + 0.003*"demonstrate" + 0.003*"spin" + 0.003*"magnetic"
# 2018-04-22 12:28:53,239 : MainThread : INFO : topic diff=1.295948, rho=0.301511
# 2018-04-22 12:28:53,324 : MainThread : INFO : PROGRESS: pass 0, at document #24000/66620
# 2018-04-22 12:28:54,066 : MainThread : INFO : optimized alpha [0.18543524, 0.23696855, 0.17563009, 0.20307086, 0.11911661, 0.12447152]
# 2018-04-22 12:28:54,071 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:28:54,116 : MainThread : INFO : topic #4 (0.119): 0.014*"cancer" + 0.012*"cells" + 0.009*"cell" + 0.006*"tumour" + 0.006*"t" + 0.006*"expression" + 0.005*"human" + 0.005*"patients" + 0.004*"1" + 0.004*"disease"
# 2018-04-22 12:28:54,118 : MainThread : INFO : topic #5 (0.124): 0.005*"species" + 0.004*"data" + 0.004*"show" + 0.004*"climate" + 0.004*"between" + 0.003*"than" + 0.003*"but" + 0.003*"their" + 0.003*"can" + 0.003*"more"
# 2018-04-22 12:28:54,120 : MainThread : INFO : topic #0 (0.185): 0.012*"cells" + 0.012*"cell" + 0.006*"protein" + 0.006*"show" + 0.005*"dna" + 0.005*"1" + 0.004*"expression" + 0.004*"mice" + 0.004*"activation" + 0.004*"binding"
# 2018-04-22 12:28:54,123 : MainThread : INFO : topic #3 (0.203): 0.006*"materials" + 0.005*"high" + 0.005*"1" + 0.004*"can" + 0.004*"2" + 0.004*"energy" + 0.004*"metal" + 0.003*"surface" + 0.003*"chemistry" + 0.003*"chemical"
# 2018-04-22 12:28:54,126 : MainThread : INFO : topic #1 (0.237): 0.006*"quantum" + 0.006*"can" + 0.004*"show" + 0.004*"spin" + 0.004*"such" + 0.004*"demonstrate" + 0.004*"single" + 0.004*"between" + 0.003*"magnetic" + 0.003*"their"
# 2018-04-22 12:28:54,129 : MainThread : INFO : topic diff=1.229606, rho=0.288675
# 2018-04-22 12:28:54,206 : MainThread : INFO : PROGRESS: pass 0, at document #26000/66620
# 2018-04-22 12:28:54,973 : MainThread : INFO : optimized alpha [0.21079645, 0.19244632, 0.19192767, 0.18822391, 0.12441452, 0.11445257]
# 2018-04-22 12:28:54,978 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:28:55,021 : MainThread : INFO : topic #5 (0.114): 0.005*"species" + 0.004*"data" + 0.004*"show" + 0.004*"between" + 0.003*"than" + 0.003*"climate" + 0.003*"but" + 0.003*"their" + 0.003*"can" + 0.003*"more"
# 2018-04-22 12:28:55,023 : MainThread : INFO : topic #4 (0.124): 0.013*"cancer" + 0.013*"cells" + 0.009*"cell" + 0.006*"expression" + 0.006*"t" + 0.005*"patients" + 0.005*"1" + 0.005*"human" + 0.005*"tumor" + 0.004*"disease"
# 2018-04-22 12:28:55,025 : MainThread : INFO : topic #2 (0.192): 0.008*"protein" + 0.006*"binding" + 0.005*"proteins" + 0.004*"2" + 0.004*"membrane" + 0.004*"cell" + 0.004*"its" + 0.004*"domain" + 0.004*"molecular" + 0.003*"activity"
# 2018-04-22 12:28:55,028 : MainThread : INFO : topic #1 (0.192): 0.006*"quantum" + 0.006*"can" + 0.004*"show" + 0.004*"single" + 0.004*"between" + 0.004*"spin" + 0.004*"such" + 0.004*"demonstrate" + 0.003*"their" + 0.003*"magnetic"
# 2018-04-22 12:28:55,030 : MainThread : INFO : topic #0 (0.211): 0.012*"cells" + 0.011*"cell" + 0.007*"protein" + 0.006*"1" + 0.005*"expression" + 0.004*"dna" + 0.004*"binding" + 0.004*"activation" + 0.004*"mice" + 0.004*"signaling"
# 2018-04-22 12:28:55,033 : MainThread : INFO : topic diff=1.606656, rho=0.277350
# 2018-04-22 12:28:55,110 : MainThread : INFO : PROGRESS: pass 0, at document #28000/66620
# 2018-04-22 12:28:55,890 : MainThread : INFO : optimized alpha [0.23942135, 0.16479719, 0.21694063, 0.17967544, 0.12788202, 0.10677069]
# 2018-04-22 12:28:55,896 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:28:55,939 : MainThread : INFO : topic #5 (0.107): 0.004*"species" + 0.004*"data" + 0.004*"show" + 0.004*"between" + 0.003*"than" + 0.003*"but" + 0.003*"more" + 0.003*"their" + 0.003*"can" + 0.003*"climate"
# 2018-04-22 12:28:55,941 : MainThread : INFO : topic #4 (0.128): 0.013*"cells" + 0.012*"cancer" + 0.009*"cell" + 0.007*"expression" + 0.005*"t" + 0.005*"tumor" + 0.005*"1" + 0.005*"human" + 0.005*"patients" + 0.004*"treatment"
# 2018-04-22 12:28:55,943 : MainThread : INFO : topic #3 (0.180): 0.006*"1" + 0.005*"high" + 0.005*"2" + 0.004*"can" + 0.004*"materials" + 0.004*"energy" + 0.004*"c" + 0.003*"chemistry" + 0.003*"structure" + 0.003*"surface"
# 2018-04-22 12:28:55,945 : MainThread : INFO : topic #2 (0.217): 0.008*"protein" + 0.007*"binding" + 0.005*"proteins" + 0.005*"2" + 0.005*"domain" + 0.005*"membrane" + 0.004*"its" + 0.004*"activity" + 0.004*"molecular" + 0.003*"but"
# 2018-04-22 12:28:55,948 : MainThread : INFO : topic #0 (0.239): 0.011*"cells" + 0.010*"cell" + 0.008*"protein" + 0.006*"1" + 0.006*"expression" + 0.005*"signaling" + 0.005*"activation" + 0.004*"induced" + 0.004*"binding" + 0.004*"activity"
# 2018-04-22 12:28:55,951 : MainThread : INFO : topic diff=1.499789, rho=0.267261
# 2018-04-22 12:28:56,030 : MainThread : INFO : PROGRESS: pass 0, at document #30000/66620
# 2018-04-22 12:28:56,790 : MainThread : INFO : optimized alpha [0.24725591, 0.15687029, 0.22644079, 0.17705096, 0.13298634, 0.10831791]
# 2018-04-22 12:28:56,795 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:28:56,839 : MainThread : INFO : topic #5 (0.108): 0.005*"species" + 0.004*"data" + 0.004*"between" + 0.003*"0" + 0.003*"than" + 0.003*"more" + 0.003*"their" + 0.003*"but" + 0.003*"during" + 0.003*"changes"
# 2018-04-22 12:28:56,841 : MainThread : INFO : topic #4 (0.133): 0.012*"cells" + 0.011*"cancer" + 0.008*"cell" + 0.007*"expression" + 0.006*"1" + 0.005*"patients" + 0.005*"tumor" + 0.005*"human" + 0.005*"treatment" + 0.005*"t"
# 2018-04-22 12:28:56,843 : MainThread : INFO : topic #3 (0.177): 0.006*"1" + 0.005*"high" + 0.005*"2" + 0.004*"can" + 0.004*"materials" + 0.004*"c" + 0.003*"structure" + 0.003*"chemistry" + 0.003*"energy" + 0.003*"surface"
# 2018-04-22 12:28:56,846 : MainThread : INFO : topic #2 (0.226): 0.008*"protein" + 0.008*"binding" + 0.005*"proteins" + 0.005*"2" + 0.005*"domain" + 0.005*"membrane" + 0.004*"its" + 0.004*"activity" + 0.003*"molecular" + 0.003*"but"
# 2018-04-22 12:28:56,848 : MainThread : INFO : topic #0 (0.247): 0.011*"cells" + 0.010*"cell" + 0.008*"protein" + 0.007*"1" + 0.006*"expression" + 0.005*"signaling" + 0.005*"activation" + 0.004*"induced" + 0.004*"binding" + 0.004*"activity"
# 2018-04-22 12:28:56,851 : MainThread : INFO : topic diff=1.591991, rho=0.258199
# 2018-04-22 12:28:56,930 : MainThread : INFO : PROGRESS: pass 0, at document #32000/66620
# 2018-04-22 12:28:57,756 : MainThread : INFO : optimized alpha [0.22053994, 0.15955801, 0.20973434, 0.17931192, 0.14007586, 0.11947036]
# 2018-04-22 12:28:57,761 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:28:57,803 : MainThread : INFO : topic #5 (0.119): 0.006*"0" + 0.005*"between" + 0.004*"species" + 0.004*"data" + 0.004*"than" + 0.003*"1" + 0.003*"more" + 0.003*"their" + 0.003*"during" + 0.003*"but"
# 2018-04-22 12:28:57,805 : MainThread : INFO : topic #4 (0.140): 0.011*"cells" + 0.009*"cancer" + 0.008*"cell" + 0.007*"patients" + 0.007*"1" + 0.006*"expression" + 0.005*"treatment" + 0.005*"2" + 0.004*"tumor" + 0.004*"human"
# 2018-04-22 12:28:57,808 : MainThread : INFO : topic #3 (0.179): 0.006*"1" + 0.005*"high" + 0.005*"2" + 0.004*"c" + 0.004*"can" + 0.003*"materials" + 0.003*"surface" + 0.003*"structure" + 0.003*"3" + 0.003*"energy"
# 2018-04-22 12:28:57,810 : MainThread : INFO : topic #2 (0.210): 0.008*"protein" + 0.007*"binding" + 0.005*"proteins" + 0.005*"2" + 0.005*"domain" + 0.004*"membrane" + 0.004*"its" + 0.004*"activity" + 0.003*"molecular" + 0.003*"but"
# 2018-04-22 12:28:57,812 : MainThread : INFO : topic #0 (0.221): 0.011*"cells" + 0.010*"cell" + 0.008*"protein" + 0.007*"1" + 0.006*"expression" + 0.005*"signaling" + 0.005*"activation" + 0.005*"induced" + 0.004*"activity" + 0.004*"receptor"
# 2018-04-22 12:28:57,815 : MainThread : INFO : topic diff=1.855193, rho=0.250000
# 2018-04-22 12:28:57,894 : MainThread : INFO : PROGRESS: pass 0, at document #34000/66620
# 2018-04-22 12:28:58,683 : MainThread : INFO : optimized alpha [0.20605628, 0.16350824, 0.19886397, 0.18071762, 0.14549308, 0.12915292]
# 2018-04-22 12:28:58,689 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:28:58,734 : MainThread : INFO : topic #5 (0.129): 0.007*"0" + 0.005*"between" + 0.004*"species" + 0.004*"data" + 0.004*"1" + 0.004*"than" + 0.003*"more" + 0.003*"during" + 0.003*"their" + 0.003*"but"
# 2018-04-22 12:28:58,736 : MainThread : INFO : topic #4 (0.145): 0.011*"cells" + 0.009*"cancer" + 0.008*"patients" + 0.008*"cell" + 0.007*"1" + 0.006*"expression" + 0.005*"treatment" + 0.005*"2" + 0.004*"0" + 0.004*"mice"
# 2018-04-22 12:28:58,739 : MainThread : INFO : topic #3 (0.181): 0.006*"1" + 0.006*"high" + 0.005*"2" + 0.004*"c" + 0.004*"can" + 0.004*"surface" + 0.003*"3" + 0.003*"materials" + 0.003*"structure" + 0.003*"0"
# 2018-04-22 12:28:58,741 : MainThread : INFO : topic #2 (0.199): 0.008*"protein" + 0.007*"binding" + 0.006*"proteins" + 0.005*"2" + 0.004*"membrane" + 0.004*"its" + 0.004*"domain" + 0.004*"activity" + 0.003*"molecular" + 0.003*"two"
# 2018-04-22 12:28:58,743 : MainThread : INFO : topic #0 (0.206): 0.011*"cells" + 0.010*"cell" + 0.007*"protein" + 0.007*"1" + 0.006*"expression" + 0.005*"induced" + 0.005*"activation" + 0.005*"signaling" + 0.004*"mice" + 0.004*"activity"
# 2018-04-22 12:28:58,746 : MainThread : INFO : topic diff=1.557087, rho=0.242536
# 2018-04-22 12:28:58,821 : MainThread : INFO : PROGRESS: pass 0, at document #36000/66620
# 2018-04-22 12:28:59,701 : MainThread : INFO : optimized alpha [0.1933753, 0.16620608, 0.19042093, 0.18111248, 0.1511226, 0.13880338]
# 2018-04-22 12:28:59,709 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:28:59,767 : MainThread : INFO : topic #5 (0.139): 0.008*"0" + 0.005*"between" + 0.004*"species" + 0.004*"1" + 0.004*"data" + 0.004*"than" + 0.003*"more" + 0.003*"during" + 0.003*"p" + 0.003*"but"
# 2018-04-22 12:28:59,773 : MainThread : INFO : topic #4 (0.151): 0.010*"cells" + 0.009*"patients" + 0.008*"cancer" + 0.007*"cell" + 0.007*"1" + 0.006*"expression" + 0.005*"treatment" + 0.005*"0" + 0.005*"2" + 0.004*"p"
# 2018-04-22 12:28:59,776 : MainThread : INFO : topic #3 (0.181): 0.007*"1" + 0.006*"high" + 0.005*"2" + 0.004*"3" + 0.004*"surface" + 0.004*"c" + 0.004*"can" + 0.003*"materials" + 0.003*"based" + 0.003*"0"
# 2018-04-22 12:28:59,779 : MainThread : INFO : topic #2 (0.190): 0.008*"protein" + 0.007*"binding" + 0.006*"proteins" + 0.005*"2" + 0.004*"membrane" + 0.004*"its" + 0.004*"activity" + 0.004*"domain" + 0.004*"molecular" + 0.003*"genes"
# 2018-04-22 12:28:59,784 : MainThread : INFO : topic #0 (0.193): 0.011*"cells" + 0.010*"cell" + 0.007*"protein" + 0.007*"1" + 0.007*"expression" + 0.005*"induced" + 0.005*"activation" + 0.005*"signaling" + 0.004*"mice" + 0.004*"activity"
# 2018-04-22 12:28:59,789 : MainThread : INFO : topic diff=1.446296, rho=0.235702
# 2018-04-22 12:28:59,870 : MainThread : INFO : PROGRESS: pass 0, at document #38000/66620
# 2018-04-22 12:29:00,845 : MainThread : INFO : optimized alpha [0.18511333, 0.1696339, 0.18319555, 0.18213284, 0.15523766, 0.14691246]
# 2018-04-22 12:29:00,851 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:29:00,898 : MainThread : INFO : topic #5 (0.147): 0.008*"0" + 0.005*"between" + 0.004*"species" + 0.004*"1" + 0.004*"than" + 0.003*"data" + 0.003*"more" + 0.003*"p" + 0.003*"during" + 0.003*"analysis"
# 2018-04-22 12:29:00,900 : MainThread : INFO : topic #4 (0.155): 0.010*"patients" + 0.010*"cells" + 0.008*"cancer" + 0.007*"1" + 0.007*"cell" + 0.006*"expression" + 0.005*"treatment" + 0.005*"0" + 0.005*"2" + 0.005*"p"
# 2018-04-22 12:29:00,902 : MainThread : INFO : topic #3 (0.182): 0.007*"1" + 0.006*"high" + 0.005*"2" + 0.004*"3" + 0.004*"surface" + 0.004*"c" + 0.004*"can" + 0.004*"materials" + 0.003*"0" + 0.003*"based"
# 2018-04-22 12:29:00,905 : MainThread : INFO : topic #2 (0.183): 0.008*"protein" + 0.006*"binding" + 0.006*"proteins" + 0.005*"2" + 0.004*"membrane" + 0.004*"its" + 0.004*"genes" + 0.004*"activity" + 0.004*"molecular" + 0.003*"domain"
# 2018-04-22 12:29:00,907 : MainThread : INFO : topic #0 (0.185): 0.012*"cells" + 0.010*"cell" + 0.007*"protein" + 0.007*"expression" + 0.007*"1" + 0.005*"induced" + 0.005*"activation" + 0.004*"mice" + 0.004*"signaling" + 0.004*"activity"
# 2018-04-22 12:29:00,911 : MainThread : INFO : topic diff=1.344344, rho=0.229416
# 2018-04-22 12:29:00,989 : MainThread : INFO : PROGRESS: pass 0, at document #40000/66620
# 2018-04-22 12:29:01,803 : MainThread : INFO : optimized alpha [0.17769858, 0.17300916, 0.17938785, 0.18296055, 0.15973879, 0.15375137]
# 2018-04-22 12:29:01,808 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:29:01,852 : MainThread : INFO : topic #5 (0.154): 0.008*"0" + 0.005*"between" + 0.004*"species" + 0.004*"1" + 0.004*"than" + 0.003*"data" + 0.003*"more" + 0.003*"p" + 0.003*"during" + 0.003*"but"
# 2018-04-22 12:29:01,854 : MainThread : INFO : topic #4 (0.160): 0.011*"patients" + 0.010*"cells" + 0.008*"cancer" + 0.007*"1" + 0.007*"cell" + 0.006*"expression" + 0.006*"0" + 0.005*"treatment" + 0.005*"2" + 0.005*"p"
# 2018-04-22 12:29:01,856 : MainThread : INFO : topic #0 (0.178): 0.012*"cells" + 0.010*"cell" + 0.007*"expression" + 0.007*"protein" + 0.006*"1" + 0.006*"induced" + 0.005*"mice" + 0.005*"activation" + 0.004*"signaling" + 0.004*"role"
# 2018-04-22 12:29:01,858 : MainThread : INFO : topic #2 (0.179): 0.008*"protein" + 0.006*"binding" + 0.006*"proteins" + 0.005*"2" + 0.004*"genes" + 0.004*"membrane" + 0.004*"activity" + 0.004*"its" + 0.004*"gene" + 0.004*"molecular"
# 2018-04-22 12:29:01,861 : MainThread : INFO : topic #3 (0.183): 0.007*"1" + 0.006*"high" + 0.005*"2" + 0.004*"3" + 0.004*"surface" + 0.004*"c" + 0.004*"materials" + 0.004*"0" + 0.004*"can" + 0.003*"energy"
# 2018-04-22 12:29:01,864 : MainThread : INFO : topic diff=1.227944, rho=0.223607
# 2018-04-22 12:29:01,938 : MainThread : INFO : PROGRESS: pass 0, at document #42000/66620
# 2018-04-22 12:29:02,712 : MainThread : INFO : optimized alpha [0.17408825, 0.17502922, 0.17698346, 0.18370828, 0.16345835, 0.16021307]
# 2018-04-22 12:29:02,717 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:29:02,761 : MainThread : INFO : topic #5 (0.160): 0.008*"0" + 0.005*"between" + 0.004*"1" + 0.004*"species" + 0.004*"than" + 0.003*"data" + 0.003*"more" + 0.003*"p" + 0.003*"during" + 0.003*"but"
# 2018-04-22 12:29:02,764 : MainThread : INFO : topic #4 (0.163): 0.011*"patients" + 0.009*"cells" + 0.008*"cancer" + 0.008*"1" + 0.007*"cell" + 0.006*"expression" + 0.006*"0" + 0.005*"treatment" + 0.005*"2" + 0.005*"p"
# 2018-04-22 12:29:02,766 : MainThread : INFO : topic #1 (0.175): 0.007*"can" + 0.004*"based" + 0.004*"system" + 0.004*"between" + 0.003*"two" + 0.003*"time" + 0.003*"model" + 0.003*"imaging" + 0.003*"optical" + 0.003*"such"
# 2018-04-22 12:29:02,769 : MainThread : INFO : topic #2 (0.177): 0.008*"protein" + 0.006*"binding" + 0.006*"proteins" + 0.005*"2" + 0.005*"genes" + 0.004*"membrane" + 0.004*"gene" + 0.004*"its" + 0.004*"activity" + 0.004*"molecular"
# 2018-04-22 12:29:02,771 : MainThread : INFO : topic #3 (0.184): 0.007*"1" + 0.006*"high" + 0.006*"2" + 0.004*"3" + 0.004*"c" + 0.004*"surface" + 0.004*"materials" + 0.004*"0" + 0.003*"can" + 0.003*"temperature"
# 2018-04-22 12:29:02,774 : MainThread : INFO : topic diff=1.184416, rho=0.218218
# 2018-04-22 12:29:02,848 : MainThread : INFO : PROGRESS: pass 0, at document #44000/66620
# 2018-04-22 12:29:03,648 : MainThread : INFO : optimized alpha [0.17026883, 0.17687359, 0.17494185, 0.18382221, 0.16737346, 0.16511746]
# 2018-04-22 12:29:03,653 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:29:03,698 : MainThread : INFO : topic #5 (0.165): 0.009*"0" + 0.005*"between" + 0.004*"1" + 0.004*"species" + 0.003*"than" + 0.003*"data" + 0.003*"p" + 0.003*"during" + 0.003*"more" + 0.003*"but"
# 2018-04-22 12:29:03,700 : MainThread : INFO : topic #4 (0.167): 0.011*"patients" + 0.009*"cells" + 0.008*"cancer" + 0.008*"1" + 0.007*"cell" + 0.006*"0" + 0.006*"expression" + 0.006*"treatment" + 0.005*"p" + 0.005*"2"
# 2018-04-22 12:29:03,703 : MainThread : INFO : topic #2 (0.175): 0.008*"protein" + 0.006*"proteins" + 0.006*"binding" + 0.005*"genes" + 0.005*"2" + 0.004*"gene" + 0.004*"membrane" + 0.004*"its" + 0.004*"molecular" + 0.004*"activity"
# 2018-04-22 12:29:03,707 : MainThread : INFO : topic #1 (0.177): 0.007*"can" + 0.004*"based" + 0.004*"system" + 0.004*"between" + 0.004*"two" + 0.003*"time" + 0.003*"model" + 0.003*"imaging" + 0.003*"field" + 0.003*"method"
# 2018-04-22 12:29:03,710 : MainThread : INFO : topic #3 (0.184): 0.007*"1" + 0.006*"high" + 0.006*"2" + 0.004*"3" + 0.004*"surface" + 0.004*"c" + 0.004*"materials" + 0.003*"temperature" + 0.003*"can" + 0.003*"0"
# 2018-04-22 12:29:03,712 : MainThread : INFO : topic diff=1.058451, rho=0.213201
# 2018-04-22 12:29:03,790 : MainThread : INFO : PROGRESS: pass 0, at document #46000/66620
# 2018-04-22 12:29:04,676 : MainThread : INFO : optimized alpha [0.16841194, 0.17930542, 0.17393744, 0.18475407, 0.16973951, 0.17041716]
# 2018-04-22 12:29:04,681 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:29:04,725 : MainThread : INFO : topic #0 (0.168): 0.013*"cells" + 0.010*"cell" + 0.008*"expression" + 0.006*"induced" + 0.006*"protein" + 0.006*"1" + 0.005*"mice" + 0.005*"activation" + 0.004*"role" + 0.004*"signaling"
# 2018-04-22 12:29:04,727 : MainThread : INFO : topic #4 (0.170): 0.012*"patients" + 0.009*"cells" + 0.008*"cancer" + 0.008*"1" + 0.007*"0" + 0.007*"cell" + 0.006*"expression" + 0.006*"treatment" + 0.006*"p" + 0.005*"2"
# 2018-04-22 12:29:04,730 : MainThread : INFO : topic #2 (0.174): 0.007*"protein" + 0.006*"proteins" + 0.005*"genes" + 0.005*"binding" + 0.005*"gene" + 0.004*"2" + 0.004*"molecular" + 0.004*"membrane" + 0.004*"its" + 0.004*"activity"
# 2018-04-22 12:29:04,733 : MainThread : INFO : topic #1 (0.179): 0.007*"can" + 0.004*"based" + 0.004*"system" + 0.004*"between" + 0.004*"two" + 0.003*"imaging" + 0.003*"time" + 0.003*"model" + 0.003*"method" + 0.003*"such"
# 2018-04-22 12:29:04,736 : MainThread : INFO : topic #3 (0.185): 0.007*"1" + 0.006*"2" + 0.006*"high" + 0.004*"c" + 0.004*"3" + 0.004*"surface" + 0.004*"materials" + 0.004*"temperature" + 0.004*"0" + 0.003*"can"
# 2018-04-22 12:29:04,739 : MainThread : INFO : topic diff=0.988111, rho=0.208514
# 2018-04-22 12:29:04,813 : MainThread : INFO : PROGRESS: pass 0, at document #48000/66620
# 2018-04-22 12:29:05,608 : MainThread : INFO : optimized alpha [0.16589996, 0.18168573, 0.17317382, 0.18373935, 0.17170207, 0.174298]
# 2018-04-22 12:29:05,614 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:29:05,656 : MainThread : INFO : topic #0 (0.166): 0.013*"cells" + 0.010*"cell" + 0.009*"expression" + 0.007*"induced" + 0.006*"protein" + 0.006*"1" + 0.006*"mice" + 0.005*"activation" + 0.004*"role" + 0.004*"signaling"
# 2018-04-22 12:29:05,659 : MainThread : INFO : topic #4 (0.172): 0.012*"patients" + 0.009*"cancer" + 0.009*"cells" + 0.008*"1" + 0.007*"0" + 0.006*"cell" + 0.006*"expression" + 0.006*"p" + 0.006*"treatment" + 0.005*"2"
# 2018-04-22 12:29:05,662 : MainThread : INFO : topic #5 (0.174): 0.009*"0" + 0.005*"between" + 0.005*"1" + 0.004*"species" + 0.004*"than" + 0.003*"data" + 0.003*"during" + 0.003*"p" + 0.003*"more" + 0.003*"but"
# 2018-04-22 12:29:05,664 : MainThread : INFO : topic #1 (0.182): 0.007*"can" + 0.004*"based" + 0.004*"system" + 0.004*"between" + 0.004*"two" + 0.003*"time" + 0.003*"imaging" + 0.003*"method" + 0.003*"model" + 0.003*"such"
# 2018-04-22 12:29:05,668 : MainThread : INFO : topic #3 (0.184): 0.007*"1" + 0.006*"2" + 0.006*"high" + 0.004*"3" + 0.004*"c" + 0.004*"surface" + 0.004*"materials" + 0.004*"temperature" + 0.004*"can" + 0.003*"0"
# 2018-04-22 12:29:05,670 : MainThread : INFO : topic diff=0.903024, rho=0.204124
# 2018-04-22 12:29:05,749 : MainThread : INFO : PROGRESS: pass 0, at document #50000/66620
# 2018-04-22 12:29:06,523 : MainThread : INFO : optimized alpha [0.16495426, 0.18187252, 0.17184114, 0.18308806, 0.17326283, 0.17726798]
# 2018-04-22 12:29:06,528 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:29:06,574 : MainThread : INFO : topic #0 (0.165): 0.013*"cells" + 0.011*"cell" + 0.009*"expression" + 0.007*"induced" + 0.006*"protein" + 0.006*"1" + 0.006*"mice" + 0.005*"activation" + 0.004*"role" + 0.004*"signaling"
# 2018-04-22 12:29:06,576 : MainThread : INFO : topic #2 (0.172): 0.007*"protein" + 0.006*"genes" + 0.006*"proteins" + 0.005*"gene" + 0.005*"binding" + 0.004*"2" + 0.004*"molecular" + 0.004*"its" + 0.004*"activity" + 0.004*"membrane"
# 2018-04-22 12:29:06,579 : MainThread : INFO : topic #5 (0.177): 0.008*"0" + 0.005*"between" + 0.005*"1" + 0.004*"species" + 0.004*"than" + 0.003*"data" + 0.003*"during" + 0.003*"p" + 0.003*"more" + 0.003*"analysis"
# 2018-04-22 12:29:06,582 : MainThread : INFO : topic #1 (0.182): 0.007*"can" + 0.004*"based" + 0.004*"two" + 0.004*"between" + 0.004*"system" + 0.004*"method" + 0.003*"imaging" + 0.003*"time" + 0.003*"field" + 0.003*"model"
# 2018-04-22 12:29:06,585 : MainThread : INFO : topic #3 (0.183): 0.007*"1" + 0.006*"high" + 0.006*"2" + 0.004*"surface" + 0.004*"c" + 0.004*"3" + 0.004*"materials" + 0.004*"temperature" + 0.003*"0" + 0.003*"can"
# 2018-04-22 12:29:06,588 : MainThread : INFO : topic diff=0.851370, rho=0.200000
# 2018-04-22 12:29:06,665 : MainThread : INFO : PROGRESS: pass 0, at document #52000/66620
# 2018-04-22 12:29:07,603 : MainThread : INFO : optimized alpha [0.15812786, 0.18076217, 0.16970536, 0.17530525, 0.18067183, 0.19787908]
# 2018-04-22 12:29:07,608 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:29:07,655 : MainThread : INFO : topic #0 (0.158): 0.013*"cells" + 0.011*"cell" + 0.009*"expression" + 0.007*"induced" + 0.006*"protein" + 0.006*"1" + 0.006*"mice" + 0.005*"activation" + 0.004*"role" + 0.004*"signaling"
# 2018-04-22 12:29:07,657 : MainThread : INFO : topic #2 (0.170): 0.007*"protein" + 0.006*"genes" + 0.005*"gene" + 0.005*"proteins" + 0.005*"binding" + 0.004*"2" + 0.004*"molecular" + 0.004*"its" + 0.004*"activity" + 0.003*"expression"
# 2018-04-22 12:29:07,660 : MainThread : INFO : topic #4 (0.181): 0.015*"patients" + 0.009*"0" + 0.009*"1" + 0.008*"cancer" + 0.007*"p" + 0.007*"cells" + 0.006*"treatment" + 0.006*"2" + 0.006*"cell" + 0.005*"clinical"
# 2018-04-22 12:29:07,663 : MainThread : INFO : topic #1 (0.181): 0.007*"can" + 0.004*"based" + 0.004*"method" + 0.004*"two" + 0.004*"model" + 0.004*"system" + 0.004*"between" + 0.004*"time" + 0.003*"such" + 0.003*"it"
# 2018-04-22 12:29:07,666 : MainThread : INFO : topic #5 (0.198): 0.010*"0" + 0.006*"1" + 0.006*"between" + 0.004*"species" + 0.003*"than" + 0.003*"p" + 0.003*"data" + 0.003*"health" + 0.003*"more" + 0.003*"during"
# 2018-04-22 12:29:07,668 : MainThread : INFO : topic diff=1.255687, rho=0.196116
# 2018-04-22 12:29:07,742 : MainThread : INFO : PROGRESS: pass 0, at document #54000/66620
# 2018-04-22 12:29:08,718 : MainThread : INFO : optimized alpha [0.15418276, 0.18105291, 0.16778691, 0.16991961, 0.18749472, 0.21894214]
# 2018-04-22 12:29:08,725 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:29:08,781 : MainThread : INFO : topic #0 (0.154): 0.014*"cells" + 0.011*"cell" + 0.009*"expression" + 0.006*"induced" + 0.006*"protein" + 0.006*"1" + 0.006*"mice" + 0.004*"role" + 0.004*"activation" + 0.004*"signaling"
# 2018-04-22 12:29:08,786 : MainThread : INFO : topic #2 (0.168): 0.007*"protein" + 0.007*"genes" + 0.006*"gene" + 0.005*"proteins" + 0.004*"binding" + 0.004*"2" + 0.004*"molecular" + 0.004*"its" + 0.004*"expression" + 0.004*"activity"
# 2018-04-22 12:29:08,791 : MainThread : INFO : topic #1 (0.181): 0.007*"can" + 0.004*"based" + 0.004*"method" + 0.004*"model" + 0.004*"two" + 0.004*"time" + 0.004*"system" + 0.004*"between" + 0.003*"it" + 0.003*"such"
# 2018-04-22 12:29:08,797 : MainThread : INFO : topic #4 (0.187): 0.016*"patients" + 0.011*"0" + 0.009*"1" + 0.008*"p" + 0.007*"cancer" + 0.006*"treatment" + 0.006*"cells" + 0.006*"2" + 0.005*"cell" + 0.005*"clinical"
# 2018-04-22 12:29:08,802 : MainThread : INFO : topic #5 (0.219): 0.010*"0" + 0.006*"1" + 0.005*"between" + 0.004*"health" + 0.004*"species" + 0.003*"data" + 0.003*"than" + 0.003*"95" + 0.003*"ci" + 0.003*"2"
# 2018-04-22 12:29:08,806 : MainThread : INFO : topic diff=1.057628, rho=0.192450
# 2018-04-22 12:29:08,882 : MainThread : INFO : PROGRESS: pass 0, at document #56000/66620
# 2018-04-22 12:29:09,755 : MainThread : INFO : optimized alpha [0.15060996, 0.18085577, 0.16651134, 0.16612901, 0.19394489, 0.23919733]
# 2018-04-22 12:29:09,761 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:29:09,807 : MainThread : INFO : topic #0 (0.151): 0.014*"cells" + 0.011*"cell" + 0.010*"expression" + 0.006*"induced" + 0.006*"mice" + 0.006*"protein" + 0.006*"1" + 0.004*"role" + 0.004*"activation" + 0.004*"signaling"
# 2018-04-22 12:29:09,810 : MainThread : INFO : topic #3 (0.166): 0.007*"1" + 0.006*"high" + 0.006*"2" + 0.004*"3" + 0.004*"c" + 0.004*"surface" + 0.004*"temperature" + 0.004*"0" + 0.004*"water" + 0.004*"materials"
# 2018-04-22 12:29:09,812 : MainThread : INFO : topic #1 (0.181): 0.007*"can" + 0.004*"based" + 0.004*"model" + 0.004*"method" + 0.004*"two" + 0.004*"time" + 0.004*"system" + 0.004*"between" + 0.003*"it" + 0.003*"such"
# 2018-04-22 12:29:09,815 : MainThread : INFO : topic #4 (0.194): 0.017*"patients" + 0.012*"0" + 0.010*"1" + 0.008*"p" + 0.007*"cancer" + 0.006*"2" + 0.006*"treatment" + 0.005*"cells" + 0.005*"clinical" + 0.005*"disease"
# 2018-04-22 12:29:09,818 : MainThread : INFO : topic #5 (0.239): 0.010*"0" + 0.006*"1" + 0.006*"between" + 0.004*"health" + 0.004*"data" + 0.003*"species" + 0.003*"95" + 0.003*"than" + 0.003*"ci" + 0.003*"2"
# 2018-04-22 12:29:09,821 : MainThread : INFO : topic diff=0.939502, rho=0.188982
# 2018-04-22 12:29:09,894 : MainThread : INFO : PROGRESS: pass 0, at document #58000/66620
# 2018-04-22 12:29:10,690 : MainThread : INFO : optimized alpha [0.14955093, 0.18313116, 0.16653877, 0.1624079, 0.20139669, 0.25782377]
# 2018-04-22 12:29:10,695 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:29:10,739 : MainThread : INFO : topic #0 (0.150): 0.014*"cells" + 0.011*"cell" + 0.010*"expression" + 0.007*"mice" + 0.006*"induced" + 0.006*"protein" + 0.005*"1" + 0.004*"role" + 0.004*"activation" + 0.004*"increased"
# 2018-04-22 12:29:10,741 : MainThread : INFO : topic #3 (0.162): 0.007*"1" + 0.006*"high" + 0.006*"2" + 0.004*"c" + 0.004*"3" + 0.004*"surface" + 0.004*"water" + 0.004*"0" + 0.004*"temperature" + 0.003*"materials"
# 2018-04-22 12:29:10,744 : MainThread : INFO : topic #1 (0.183): 0.007*"can" + 0.005*"based" + 0.005*"model" + 0.004*"method" + 0.004*"time" + 0.004*"system" + 0.004*"two" + 0.004*"between" + 0.003*"it" + 0.003*"different"
# 2018-04-22 12:29:10,747 : MainThread : INFO : topic #4 (0.201): 0.017*"patients" + 0.013*"0" + 0.010*"1" + 0.009*"p" + 0.007*"2" + 0.007*"cancer" + 0.006*"treatment" + 0.005*"clinical" + 0.005*"cells" + 0.005*"disease"
# 2018-04-22 12:29:10,750 : MainThread : INFO : topic #5 (0.258): 0.010*"0" + 0.006*"1" + 0.006*"between" + 0.005*"health" + 0.004*"data" + 0.003*"species" + 0.003*"than" + 0.003*"95" + 0.003*"2" + 0.003*"ci"
# 2018-04-22 12:29:10,752 : MainThread : INFO : topic diff=0.819540, rho=0.185695
# 2018-04-22 12:29:10,823 : MainThread : INFO : PROGRESS: pass 0, at document #60000/66620
# 2018-04-22 12:29:11,623 : MainThread : INFO : optimized alpha [0.14861365, 0.18383309, 0.16628012, 0.15959793, 0.20858964, 0.27589679]
# 2018-04-22 12:29:11,628 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:29:11,671 : MainThread : INFO : topic #0 (0.149): 0.015*"cells" + 0.011*"cell" + 0.011*"expression" + 0.007*"mice" + 0.006*"induced" + 0.006*"protein" + 0.005*"1" + 0.004*"role" + 0.004*"activation" + 0.004*"increased"
# 2018-04-22 12:29:11,673 : MainThread : INFO : topic #3 (0.160): 0.007*"1" + 0.006*"high" + 0.006*"2" + 0.004*"c" + 0.004*"3" + 0.004*"water" + 0.004*"temperature" + 0.004*"0" + 0.004*"surface" + 0.004*"5"
# 2018-04-22 12:29:11,676 : MainThread : INFO : topic #1 (0.184): 0.007*"can" + 0.005*"model" + 0.005*"based" + 0.004*"method" + 0.004*"time" + 0.004*"two" + 0.004*"between" + 0.004*"system" + 0.004*"it" + 0.003*"different"
# 2018-04-22 12:29:11,679 : MainThread : INFO : topic #4 (0.209): 0.018*"patients" + 0.015*"0" + 0.010*"1" + 0.010*"p" + 0.007*"2" + 0.006*"cancer" + 0.006*"treatment" + 0.005*"clinical" + 0.005*"3" + 0.005*"disease"
# 2018-04-22 12:29:11,682 : MainThread : INFO : topic #5 (0.276): 0.010*"0" + 0.006*"1" + 0.006*"between" + 0.005*"health" + 0.004*"data" + 0.004*"95" + 0.004*"ci" + 0.003*"than" + 0.003*"2" + 0.003*"species"
# 2018-04-22 12:29:11,684 : MainThread : INFO : topic diff=0.720223, rho=0.182574
# 2018-04-22 12:29:11,758 : MainThread : INFO : PROGRESS: pass 0, at document #62000/66620
# 2018-04-22 12:29:12,577 : MainThread : INFO : optimized alpha [0.14827088, 0.18578848, 0.16701651, 0.15701284, 0.21577851, 0.29163876]
# 2018-04-22 12:29:12,582 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:29:12,629 : MainThread : INFO : topic #0 (0.148): 0.016*"cells" + 0.012*"cell" + 0.011*"expression" + 0.007*"mice" + 0.006*"induced" + 0.006*"protein" + 0.005*"1" + 0.004*"role" + 0.004*"activation" + 0.004*"levels"
# 2018-04-22 12:29:12,631 : MainThread : INFO : topic #3 (0.157): 0.007*"1" + 0.006*"2" + 0.006*"high" + 0.004*"c" + 0.004*"3" + 0.004*"temperature" + 0.004*"water" + 0.004*"0" + 0.004*"surface" + 0.003*"5"
# 2018-04-22 12:29:12,634 : MainThread : INFO : topic #1 (0.186): 0.006*"can" + 0.005*"model" + 0.005*"based" + 0.005*"method" + 0.004*"time" + 0.004*"two" + 0.004*"between" + 0.004*"system" + 0.004*"it" + 0.003*"different"
# 2018-04-22 12:29:12,637 : MainThread : INFO : topic #4 (0.216): 0.018*"patients" + 0.016*"0" + 0.010*"1" + 0.010*"p" + 0.007*"2" + 0.006*"cancer" + 0.006*"treatment" + 0.005*"3" + 0.005*"clinical" + 0.005*"disease"
# 2018-04-22 12:29:12,640 : MainThread : INFO : topic #5 (0.292): 0.010*"0" + 0.006*"1" + 0.006*"between" + 0.005*"health" + 0.004*"data" + 0.004*"95" + 0.004*"ci" + 0.003*"species" + 0.003*"than" + 0.003*"2"
# 2018-04-22 12:29:12,642 : MainThread : INFO : topic diff=0.644995, rho=0.179605
# 2018-04-22 12:29:12,716 : MainThread : INFO : PROGRESS: pass 0, at document #64000/66620
# 2018-04-22 12:29:13,523 : MainThread : INFO : optimized alpha [0.14887598, 0.18746403, 0.16846107, 0.15570441, 0.22107862, 0.30643639]
# ...
# 2018-04-22 12:31:11,944 : MainThread : INFO : topic #2 (0.203): 0.008*"protein" + 0.007*"genes" + 0.006*"binding" + 0.006*"gene" + 0.006*"proteins" + 0.005*"dna" + 0.005*"molecular" + 0.004*"its" + 0.004*"two" + 0.003*"identified"
# 2018-04-22 12:31:11,947 : MainThread : INFO : topic #1 (0.208): 0.007*"can" + 0.005*"based" + 0.004*"model" + 0.004*"between" + 0.004*"system" + 0.004*"method" + 0.004*"time" + 0.004*"two" + 0.004*"imaging" + 0.004*"brain"
# 2018-04-22 12:31:11,949 : MainThread : INFO : topic diff=0.115552, rho=0.161564
# 2018-04-22 12:31:12,016 : MainThread : INFO : PROGRESS: pass 4, at document #50000/66620
# 2018-04-22 12:31:12,761 : MainThread : INFO : optimized alpha [0.20156275, 0.20848686, 0.20097543, 0.16966745, 0.17126618, 0.16125703]
# 2018-04-22 12:31:12,766 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:31:12,812 : MainThread : INFO : topic #5 (0.161): 0.006*"species" + 0.004*"between" + 0.004*"during" + 0.004*"their" + 0.004*"than" + 0.003*"more" + 0.003*"data" + 0.003*"but" + 0.003*"may" + 0.003*"population"
# 2018-04-22 12:31:12,815 : MainThread : INFO : topic #3 (0.170): 0.006*"high" + 0.006*"1" + 0.005*"2" + 0.005*"surface" + 0.004*"materials" + 0.004*"energy" + 0.004*"temperature" + 0.004*"can" + 0.004*"properties" + 0.004*"c"
# 2018-04-22 12:31:12,818 : MainThread : INFO : topic #2 (0.201): 0.008*"protein" + 0.007*"genes" + 0.006*"binding" + 0.006*"gene" + 0.006*"proteins" + 0.005*"dna" + 0.005*"molecular" + 0.004*"its" + 0.004*"two" + 0.004*"identified"
# 2018-04-22 12:31:12,820 : MainThread : INFO : topic #0 (0.202): 0.018*"cells" + 0.014*"cell" + 0.011*"expression" + 0.007*"mice" + 0.007*"induced" + 0.005*"cancer" + 0.004*"human" + 0.004*"activation" + 0.004*"protein" + 0.004*"1"
# 2018-04-22 12:31:12,823 : MainThread : INFO : topic #1 (0.208): 0.007*"can" + 0.004*"based" + 0.004*"model" + 0.004*"between" + 0.004*"method" + 0.004*"two" + 0.004*"system" + 0.004*"time" + 0.004*"imaging" + 0.004*"brain"
# 2018-04-22 12:31:12,826 : MainThread : INFO : topic diff=0.115142, rho=0.161564
# 2018-04-22 12:31:12,890 : MainThread : INFO : PROGRESS: pass 4, at document #52000/66620
# 2018-04-22 12:31:13,673 : MainThread : INFO : optimized alpha [0.1927689, 0.20851389, 0.19663607, 0.16439113, 0.18160309, 0.17490715]
# 2018-04-22 12:31:13,678 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:31:13,722 : MainThread : INFO : topic #3 (0.164): 0.006*"high" + 0.006*"1" + 0.005*"2" + 0.005*"surface" + 0.004*"materials" + 0.004*"energy" + 0.004*"temperature" + 0.004*"can" + 0.004*"c" + 0.004*"properties"
# 2018-04-22 12:31:13,724 : MainThread : INFO : topic #5 (0.175): 0.006*"species" + 0.005*"between" + 0.004*"their" + 0.004*"more" + 0.003*"during" + 0.003*"data" + 0.003*"than" + 0.003*"health" + 0.003*"but" + 0.003*"may"
# 2018-04-22 12:31:13,726 : MainThread : INFO : topic #0 (0.193): 0.018*"cells" + 0.015*"cell" + 0.012*"expression" + 0.007*"mice" + 0.007*"induced" + 0.005*"cancer" + 0.004*"human" + 0.004*"protein" + 0.004*"increased" + 0.004*"activation"
# 2018-04-22 12:31:13,729 : MainThread : INFO : topic #2 (0.197): 0.008*"protein" + 0.007*"genes" + 0.006*"gene" + 0.006*"binding" + 0.006*"proteins" + 0.005*"dna" + 0.005*"molecular" + 0.004*"two" + 0.004*"its" + 0.004*"identified"
# 2018-04-22 12:31:13,731 : MainThread : INFO : topic #1 (0.209): 0.007*"can" + 0.005*"model" + 0.005*"based" + 0.004*"between" + 0.004*"method" + 0.004*"two" + 0.004*"time" + 0.004*"system" + 0.003*"it" + 0.003*"different"
# 2018-04-22 12:31:13,734 : MainThread : INFO : topic diff=0.205978, rho=0.161564
# 2018-04-22 12:31:13,796 : MainThread : INFO : PROGRESS: pass 4, at document #54000/66620
# 2018-04-22 12:31:14,589 : MainThread : INFO : optimized alpha [0.18748978, 0.20989767, 0.19323854, 0.16069689, 0.19234253, 0.18895407]
# 2018-04-22 12:31:14,594 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:31:14,637 : MainThread : INFO : topic #3 (0.161): 0.006*"high" + 0.006*"1" + 0.005*"2" + 0.005*"surface" + 0.004*"materials" + 0.004*"temperature" + 0.004*"energy" + 0.004*"c" + 0.004*"can" + 0.004*"properties"
# 2018-04-22 12:31:14,639 : MainThread : INFO : topic #0 (0.187): 0.019*"cells" + 0.015*"cell" + 0.012*"expression" + 0.007*"mice" + 0.007*"induced" + 0.005*"cancer" + 0.005*"human" + 0.004*"protein" + 0.004*"increased" + 0.004*"1"
# 2018-04-22 12:31:14,641 : MainThread : INFO : topic #4 (0.192): 0.023*"0" + 0.015*"1" + 0.015*"patients" + 0.011*"p" + 0.009*"2" + 0.007*"3" + 0.005*"associated" + 0.005*"95" + 0.005*"5" + 0.005*"risk"
# 2018-04-22 12:31:14,644 : MainThread : INFO : topic #2 (0.193): 0.008*"protein" + 0.007*"genes" + 0.007*"gene" + 0.006*"proteins" + 0.005*"binding" + 0.005*"dna" + 0.004*"molecular" + 0.004*"two" + 0.004*"identified" + 0.004*"its"
# 2018-04-22 12:31:14,646 : MainThread : INFO : topic #1 (0.210): 0.007*"can" + 0.005*"model" + 0.005*"based" + 0.004*"method" + 0.004*"between" + 0.004*"two" + 0.004*"time" + 0.004*"system" + 0.003*"it" + 0.003*"different"
# 2018-04-22 12:31:14,649 : MainThread : INFO : topic diff=0.172720, rho=0.161564
# 2018-04-22 12:31:14,713 : MainThread : INFO : PROGRESS: pass 4, at document #56000/66620
# 2018-04-22 12:31:15,506 : MainThread : INFO : optimized alpha [0.18298724, 0.20971213, 0.19035251, 0.15794361, 0.20304064, 0.20241326]
# 2018-04-22 12:31:15,512 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:31:15,555 : MainThread : INFO : topic #3 (0.158): 0.006*"high" + 0.006*"1" + 0.005*"2" + 0.005*"surface" + 0.004*"materials" + 0.004*"energy" + 0.004*"temperature" + 0.004*"can" + 0.004*"properties" + 0.004*"c"
# 2018-04-22 12:31:15,557 : MainThread : INFO : topic #0 (0.183): 0.019*"cells" + 0.015*"cell" + 0.012*"expression" + 0.007*"mice" + 0.007*"induced" + 0.005*"cancer" + 0.005*"human" + 0.004*"increased" + 0.004*"protein" + 0.004*"levels"
# 2018-04-22 12:31:15,560 : MainThread : INFO : topic #5 (0.202): 0.005*"species" + 0.005*"health" + 0.005*"between" + 0.004*"their" + 0.004*"data" + 0.004*"more" + 0.003*"than" + 0.003*"during" + 0.003*"population" + 0.003*"may"
# 2018-04-22 12:31:15,562 : MainThread : INFO : topic #4 (0.203): 0.024*"0" + 0.016*"1" + 0.015*"patients" + 0.011*"p" + 0.009*"2" + 0.007*"3" + 0.006*"95" + 0.005*"5" + 0.005*"associated" + 0.005*"risk"
# 2018-04-22 12:31:15,564 : MainThread : INFO : topic #1 (0.210): 0.007*"can" + 0.005*"model" + 0.005*"based" + 0.004*"method" + 0.004*"between" + 0.004*"time" + 0.004*"two" + 0.004*"system" + 0.003*"it" + 0.003*"different"
# 2018-04-22 12:31:15,567 : MainThread : INFO : topic diff=0.152043, rho=0.161564
# 2018-04-22 12:31:15,635 : MainThread : INFO : PROGRESS: pass 4, at document #58000/66620
# 2018-04-22 12:31:16,414 : MainThread : INFO : optimized alpha [0.18133022, 0.21186391, 0.18916494, 0.15530282, 0.2142088, 0.21510512]
# 2018-04-22 12:31:16,420 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:31:16,465 : MainThread : INFO : topic #3 (0.155): 0.006*"high" + 0.006*"1" + 0.005*"2" + 0.005*"surface" + 0.004*"energy" + 0.004*"temperature" + 0.004*"materials" + 0.004*"c" + 0.004*"water" + 0.004*"can"
# 2018-04-22 12:31:16,467 : MainThread : INFO : topic #0 (0.181): 0.018*"cells" + 0.015*"cell" + 0.012*"expression" + 0.007*"mice" + 0.007*"induced" + 0.005*"human" + 0.004*"cancer" + 0.004*"increased" + 0.004*"protein" + 0.004*"levels"
# 2018-04-22 12:31:16,470 : MainThread : INFO : topic #1 (0.212): 0.007*"can" + 0.005*"model" + 0.005*"based" + 0.005*"method" + 0.004*"between" + 0.004*"time" + 0.004*"two" + 0.004*"system" + 0.003*"data" + 0.003*"it"
# 2018-04-22 12:31:16,472 : MainThread : INFO : topic #4 (0.214): 0.024*"0" + 0.016*"1" + 0.015*"patients" + 0.012*"p" + 0.009*"2" + 0.007*"3" + 0.006*"5" + 0.005*"95" + 0.005*"risk" + 0.005*"associated"
# 2018-04-22 12:31:16,475 : MainThread : INFO : topic #5 (0.215): 0.005*"species" + 0.005*"health" + 0.005*"between" + 0.004*"their" + 0.004*"data" + 0.004*"more" + 0.003*"than" + 0.003*"during" + 0.003*"population" + 0.003*"but"
# 2018-04-22 12:31:16,481 : MainThread : INFO : topic diff=0.140468, rho=0.161564
# 2018-04-22 12:31:16,546 : MainThread : INFO : PROGRESS: pass 4, at document #60000/66620
# 2018-04-22 12:31:17,329 : MainThread : INFO : optimized alpha [0.1799784, 0.21255636, 0.18789825, 0.15318175, 0.22559802, 0.2278035]
# 2018-04-22 12:31:17,334 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:31:17,377 : MainThread : INFO : topic #3 (0.153): 0.006*"high" + 0.006*"1" + 0.005*"2" + 0.005*"surface" + 0.004*"energy" + 0.004*"temperature" + 0.004*"materials" + 0.004*"c" + 0.004*"water" + 0.004*"can"
# 2018-04-22 12:31:17,379 : MainThread : INFO : topic #0 (0.180): 0.018*"cells" + 0.015*"cell" + 0.013*"expression" + 0.008*"mice" + 0.007*"induced" + 0.004*"increased" + 0.004*"human" + 0.004*"cancer" + 0.004*"levels" + 0.004*"protein"
# 2018-04-22 12:31:17,381 : MainThread : INFO : topic #1 (0.213): 0.007*"can" + 0.005*"model" + 0.005*"based" + 0.005*"method" + 0.004*"between" + 0.004*"time" + 0.004*"two" + 0.004*"data" + 0.004*"system" + 0.004*"it"
# 2018-04-22 12:31:17,383 : MainThread : INFO : topic #4 (0.226): 0.025*"0" + 0.015*"1" + 0.015*"patients" + 0.012*"p" + 0.009*"2" + 0.007*"3" + 0.006*"5" + 0.006*"95" + 0.005*"4" + 0.005*"risk"
# 2018-04-22 12:31:17,385 : MainThread : INFO : topic #5 (0.228): 0.005*"health" + 0.005*"species" + 0.005*"between" + 0.004*"their" + 0.004*"data" + 0.004*"more" + 0.003*"than" + 0.003*"during" + 0.003*"population" + 0.003*"but"
# 2018-04-22 12:31:17,388 : MainThread : INFO : topic diff=0.131629, rho=0.161564
# 2018-04-22 12:31:17,453 : MainThread : INFO : PROGRESS: pass 4, at document #62000/66620
# 2018-04-22 12:31:18,218 : MainThread : INFO : optimized alpha [0.17904408, 0.21402237, 0.18787985, 0.1513471, 0.2357156, 0.23916985]
# 2018-04-22 12:31:18,223 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:31:18,267 : MainThread : INFO : topic #3 (0.151): 0.006*"high" + 0.006*"1" + 0.005*"2" + 0.005*"surface" + 0.004*"temperature" + 0.004*"energy" + 0.004*"c" + 0.004*"materials" + 0.004*"water" + 0.003*"can"
# 2018-04-22 12:31:18,269 : MainThread : INFO : topic #0 (0.179): 0.019*"cells" + 0.015*"cell" + 0.013*"expression" + 0.008*"mice" + 0.007*"induced" + 0.005*"human" + 0.004*"increased" + 0.004*"levels" + 0.004*"cancer" + 0.004*"protein"
# 2018-04-22 12:31:18,271 : MainThread : INFO : topic #1 (0.214): 0.006*"can" + 0.006*"model" + 0.005*"based" + 0.005*"method" + 0.004*"time" + 0.004*"between" + 0.004*"two" + 0.004*"data" + 0.004*"system" + 0.004*"it"
# 2018-04-22 12:31:18,274 : MainThread : INFO : topic #4 (0.236): 0.025*"0" + 0.015*"1" + 0.015*"patients" + 0.012*"p" + 0.009*"2" + 0.007*"3" + 0.006*"5" + 0.006*"95" + 0.005*"4" + 0.005*"risk"
# 2018-04-22 12:31:18,276 : MainThread : INFO : topic #5 (0.239): 0.006*"health" + 0.005*"species" + 0.005*"between" + 0.004*"data" + 0.004*"their" + 0.004*"more" + 0.003*"than" + 0.003*"population" + 0.003*"during" + 0.003*"but"
# 2018-04-22 12:31:18,279 : MainThread : INFO : topic diff=0.128770, rho=0.161564
# 2018-04-22 12:31:18,342 : MainThread : INFO : PROGRESS: pass 4, at document #64000/66620
# 2018-04-22 12:31:19,113 : MainThread : INFO : optimized alpha [0.17944135, 0.21543656, 0.18871313, 0.15038775, 0.24530464, 0.25057194]
# 2018-04-22 12:31:19,118 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:31:19,161 : MainThread : INFO : topic #3 (0.150): 0.006*"1" + 0.006*"high" + 0.005*"2" + 0.005*"surface" + 0.004*"temperature" + 0.004*"energy" + 0.004*"water" + 0.004*"c" + 0.003*"materials" + 0.003*"can"
# 2018-04-22 12:31:19,162 : MainThread : INFO : topic #0 (0.179): 0.019*"cells" + 0.015*"cell" + 0.013*"expression" + 0.008*"mice" + 0.007*"induced" + 0.005*"increased" + 0.005*"levels" + 0.005*"human" + 0.004*"protein" + 0.004*"cancer"
# 2018-04-22 12:31:19,165 : MainThread : INFO : topic #1 (0.215): 0.006*"can" + 0.006*"model" + 0.005*"based" + 0.005*"method" + 0.004*"between" + 0.004*"time" + 0.004*"data" + 0.004*"two" + 0.004*"used" + 0.004*"it"
# 2018-04-22 12:31:19,167 : MainThread : INFO : topic #4 (0.245): 0.026*"0" + 0.016*"1" + 0.015*"patients" + 0.012*"p" + 0.009*"2" + 0.007*"3" + 0.006*"95" + 0.006*"5" + 0.005*"ci" + 0.005*"4"
# 2018-04-22 12:31:19,170 : MainThread : INFO : topic #5 (0.251): 0.006*"health" + 0.005*"species" + 0.005*"between" + 0.004*"data" + 0.004*"their" + 0.004*"more" + 0.003*"than" + 0.003*"population" + 0.003*"during" + 0.003*"among"
# 2018-04-22 12:31:19,173 : MainThread : INFO : topic diff=0.119878, rho=0.161564
# 2018-04-22 12:31:19,236 : MainThread : INFO : PROGRESS: pass 4, at document #66000/66620
# 2018-04-22 12:31:20,004 : MainThread : INFO : optimized alpha [0.18051812, 0.21609548, 0.18863943, 0.14953333, 0.25492153, 0.26118666]
# 2018-04-22 12:31:20,009 : MainThread : INFO : merging changes from 2000 documents into a model of 66620 documents
# 2018-04-22 12:31:20,052 : MainThread : INFO : topic #3 (0.150): 0.006*"1" + 0.006*"high" + 0.005*"2" + 0.004*"surface" + 0.004*"temperature" + 0.004*"energy" + 0.004*"water" + 0.004*"c" + 0.003*"can" + 0.003*"degrees"
# 2018-04-22 12:31:20,054 : MainThread : INFO : topic #0 (0.181): 0.019*"cells" + 0.014*"cell" + 0.013*"expression" + 0.008*"mice" + 0.007*"induced" + 0.005*"levels" + 0.005*"increased" + 0.004*"human" + 0.004*"protein" + 0.004*"cancer"
# 2018-04-22 12:31:20,056 : MainThread : INFO : topic #1 (0.216): 0.006*"can" + 0.006*"model" + 0.005*"based" + 0.005*"method" + 0.004*"between" + 0.004*"time" + 0.004*"data" + 0.004*"two" + 0.004*"used" + 0.004*"it"
# 2018-04-22 12:31:20,058 : MainThread : INFO : topic #4 (0.255): 0.026*"0" + 0.016*"1" + 0.015*"patients" + 0.013*"p" + 0.009*"2" + 0.007*"3" + 0.006*"95" + 0.006*"5" + 0.006*"ci" + 0.005*"4"
# 2018-04-22 12:31:20,061 : MainThread : INFO : topic #5 (0.261): 0.006*"health" + 0.005*"species" + 0.005*"between" + 0.004*"data" + 0.004*"their" + 0.004*"more" + 0.003*"population" + 0.003*"than" + 0.003*"during" + 0.003*"among"
# 2018-04-22 12:31:20,064 : MainThread : INFO : topic diff=0.115467, rho=0.161564
# 2018-04-22 12:31:20,127 : MainThread : INFO : PROGRESS: pass 4, at document #66620/66620
# 2018-04-22 12:31:20,373 : MainThread : INFO : optimized alpha [0.17862999, 0.21590178, 0.18653214, 0.1471439, 0.26609066, 0.27105248]
# 2018-04-22 12:31:20,378 : MainThread : INFO : merging changes from 620 documents into a model of 66620 documents
# 2018-04-22 12:31:20,420 : MainThread : INFO : topic #3 (0.147): 0.006*"1" + 0.006*"high" + 0.005*"2" + 0.004*"energy" + 0.004*"surface" + 0.004*"temperature" + 0.004*"water" + 0.004*"c" + 0.003*"degrees" + 0.003*"properties"
# 2018-04-22 12:31:20,422 : MainThread : INFO : topic #0 (0.179): 0.019*"cells" + 0.014*"cell" + 0.014*"expression" + 0.008*"mice" + 0.007*"induced" + 0.005*"levels" + 0.005*"increased" + 0.005*"human" + 0.004*"protein" + 0.004*"cancer"
# 2018-04-22 12:31:20,425 : MainThread : INFO : topic #1 (0.216): 0.006*"can" + 0.006*"model" + 0.005*"based" + 0.005*"method" + 0.004*"between" + 0.004*"time" + 0.004*"two" + 0.004*"data" + 0.004*"used" + 0.004*"different"
# 2018-04-22 12:31:20,427 : MainThread : INFO : topic #4 (0.266): 0.026*"0" + 0.016*"1" + 0.015*"patients" + 0.012*"p" + 0.009*"2" + 0.007*"3" + 0.006*"95" + 0.006*"5" + 0.006*"ci" + 0.006*"risk"
# 2018-04-22 12:31:20,429 : MainThread : INFO : topic #5 (0.271): 0.006*"health" + 0.005*"species" + 0.005*"between" + 0.004*"data" + 0.004*"their" + 0.004*"more" + 0.003*"population" + 0.003*"than" + 0.003*"during" + 0.003*"among"
# 2018-04-22 12:31:20,432 : MainThread : INFO : topic diff=0.108882, rho=0.161564

# %% [markdown]
# You can refer to [this notebook](lda_training_tips.ipynb) also before training the LDA model. It contains tips and suggestions for pre-processing the text data, and how to train the LDA model to get good results.

# %% [markdown]
# ## Doc-Topic distribution
#
# Now we will use `get_document_topics` which infers the topic distribution of a document. It basically returns a list of (topic_id, topic_probability) for each document in the input corpus.

# %%
# Get document topics
all_topics = model.get_document_topics(corpus, minimum_probability=0)
all_topics[0]
# Out:
# [(0, 0.39545888),
#  (1, 0.0017428111),
#  (2, 0.59718239),
#  (3, 0.0011685896),
#  (4, 0.0022194292),
#  (5, 0.0022278947)]

# %% [markdown]
# The above output shows the topic distribution of first document in the corpus as a list of (topic_id, topic_probability).
#
# Now, using the topic distribution of a document as it's vector embedding, we will plot all the documents in our corpus using Tensorboard.

# %% [markdown]
# ## Prepare the Input files for Tensorboard
#
# Tensorboard takes two input files, one containing the embedding vectors and the other containing relevant metadata. As described above we will use the topic distribution of documents as their embedding vector. Metadata file will consist of Movie titles with their genres.

# %%
# create file for tensors
with open('doc_lda_tensor.tsv','w') as w:
    for doc_topics in all_topics:
        for topics in doc_topics:
            w.write(str(topics[1])+ "\t")
        w.write("\n")
        
# create file for metadata
with open('doc_lda_metadata.tsv','w') as w:
    w.write('Titles\ttitle\n')
    for j, k in zip(dataframe.title, dataframe.abstract):
        w.write("%s\t%s\n" % (j, k))

# %% [markdown]
# Now you can go to http://projector.tensorflow.org/ and upload these two files by clicking on Load data in the left panel.
#
# For demo purposes I have uploaded the LDA doc-topic embeddings generated from the model trained above [here](https://github.com/parulsethi/LdaProjector/). You can also access the Embedding projector configured with these uploaded embeddings at this [link](http://projector.tensorflow.org/?config=https://raw.githubusercontent.com/parulsethi/LdaProjector/master/doc_lda_config.json).

# %% [markdown]
# ## Visualize using PCA
#
# The Embedding Projector computes the top 10 principal components. The menu at the left panel lets you project those components onto any combination of two or three.
# <img src="doc_lda_pca.png">
# From PCA, we get a simplex (tetrahedron in this case) where each data point represent a document. These data points are  colored according to their Genres which were given in the Movie dataset.
#
# As we can see there are a lot of points which cluster at the corners of the simplex. This is primarily due to the sparsity of vectors we are using. The documents at the corners primarily belongs to a single topic (hence, large weight in a single dimension and other dimensions have approximately zero weight.) You can modify the metadata file as explained below to see the dimension weights along with the Movie title.
#
# Now, we will append the topics with highest probability (topic_id, topic_probability) to the document's title, in order to explore what topics do the cluster corners or edges dominantly belong to. For this, we just need to overwrite the metadata file as below:

# %%
tensors = []
for doc_topics in all_topics:
    doc_tensor = []
    for topic in doc_topics:
        if round(topic[1], 3) > 0:
            doc_tensor.append((topic[0], float(round(topic[1], 3))))
    # sort topics according to highest probabilities
    doc_tensor = sorted(doc_tensor, key=lambda x: x[1], reverse=True)
    # store vectors to add in metadata file
    tensors.append(doc_tensor[:5])

# overwrite metadata file
i=0
with open('doc_lda_metadata.tsv','w') as w:
    w.write('Titles\tGenres\n')
    for j,k in zip(dataframe.title, dataframe.label):
        w.write("%s\t%s\n" % (''.join((str(j), str(tensors[i]))),k))
        i+=1

# %% [markdown]
# Next, we upload the previous tensor file "doc_lda_tensor.tsv" and this new metadata file to http://projector.tensorflow.org/ .
# <img src="topic_with_coordinate.png">
# Voila! Now we can click on any point to see it's top topics with their probabilty in that document, along with the title. As we can see in the above example, "Beverly hill cops" primarily belongs to the 0th and 1st topic as they have the highest probability amongst all.
#
#
#
# ## Visualize using T-SNE
#
# In T-SNE, the data is visualized by animating through every iteration of the t-sne algorithm. The t-sne menu at the left lets you adjust the value of it's two hyperparameters. The first one is Perplexity, which is basically a measure of information. It may be viewed as a knob that sets the number of effective nearest neighbors[2]. The second one is learning rate that defines how quickly an algorithm learns on encountering new examples/data points.
#
# Now, as the topic distribution of a document is used as it’s embedding vector, t-sne ends up forming clusters of documents belonging to same topics. In order to understand and interpret about the theme of those topics, we can use `show_topic()` to explore the terms that the topics consisted of.
#
# <img src="doc_lda_tsne.png">
#
# The above plot was generated with perplexity 11, learning rate 10 and iteration 1100. Though the results could vary on successive runs, and you may not get the exact plot as above even with same hyperparameter settings. But some small clusters will start forming as above, with different orientations.
#
# I named some clusters above based on the genre of it's movies and also using the `show_topic()` to see relevant terms of the topic which was most prevelant in a cluster. Most of the clusters had doocumets belonging dominantly to a single topic. For ex. The cluster with movies belonging primarily to topic 0 could be named Fantasy/Romance based on terms displayed below for topic 0. You can play with the visualization yourself on this [link](http://projector.tensorflow.org/?config=https://raw.githubusercontent.com/parulsethi/LdaProjector/master/doc_lda_config.json) and try to conclude a label for clusters based on movies it has and their dominant topic. You can see the top 5 topics of every point by hovering over it.
#
# Now, we can notice that their are more than 10 clusters in the above image, whereas we trained our model for `num_topics=10`. It's because their are few clusters, which has documents belonging to more than one topic with an approximately close topic probability values.

# %%
model.show_topic(topicid=0, topn=15)
# Out:
# [('cells', 0.019363862),
#  ('cell', 0.014119518),
#  ('expression', 0.01352202),
#  ('mice', 0.007646814),
#  ('induced', 0.0065615214),
#  ('levels', 0.0050926651),
#  ('increased', 0.004751916),
#  ('human', 0.0045997747),
#  ('protein', 0.0044072135),
#  ('cancer', 0.0042670672),
#  ('il', 0.0038744663),
#  ('role', 0.0038231616),
#  ('1', 0.0036225135),
#  ('activity', 0.003570609),
#  ('t', 0.0035296546)]

# %% [markdown]
# You can even use pyLDAvis to deduce topics more efficiently. It provides a deeper inspection of the terms highly associated with each individual topic. For this, it uses a measure called **relevance** of a term to a topic that allows users to flexibly rank terms best suited for a meaningful topic interpretation. It's weight parameter called λ can be adjusted to display useful terms which could help in differentiating topics efficiently.

# %%
import pyLDAvis.gensim

viz = pyLDAvis.gensim.prepare(model, corpus, dictionary)
pyLDAvis.display(viz)
# Out:
# /Users/Shemelis/anaconda/lib/python3.6/site-packages/pyLDAvis/_prepare.py:387: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   topic_term_dists = topic_term_dists.ix[topic_order]
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el907113515835088159216210"></div>
# <script type="text/javascript">
#
# var ldavis_el907113515835088159216210_data = {"mdsDat": {"Freq": [20.764076232910156, 19.085594177246094, 16.29880142211914, 16.269512176513672, 15.562134742736816, 12.019883155822754], "cluster": [1, 1, 1, 1, 1, 1], "topics": [1, 2, 3, 4, 5, 6], "x": [0.24605967668393772, 0.13829146340145082, -0.1279679792799935, -0.08939154833001565, -0.10204256438652393, -0.0649490480888555], "y": [0.05959545096109425, -0.0744474659419778, 0.037089212193385214, 0.2570052760577175, -0.14059626601190936, -0.1386462072583096]}, "tinfo": {"Category": ["Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4",  ...

# %%
pyLDAvis.save_json(viz,"Viz_InterTopic_distance_map")

# %% [markdown]
# The weight parameter λ can be viewed as a knob to adjust the ranks of the terms based on whether they are simply ranked according to their probability in the topic (λ=1) or are normalized by their marginal probability across the corpus (λ=0). Setting λ=1 could result in similar ranking of terms for large no. of topics hence making it difficult to differentiate between them, and setting λ=0 ranks terms solely based on their exclusiveness to current topic which could result in such rare terms that occur in only a single topic and hence the topics may remain difficult to interpret. [(Sievert and Shirley 2014)](https://nlp.stanford.edu/events/illvi2014/papers/sievert-illvi2014.pdf) suggested the optimal value of λ=0.6 based on a user study.

# %% [markdown]
# # Conclusion
#
# We learned about visualizing the Document Embeddings and LDA Doc-topic distributions through Tensorboard's Embedding Projector. It is a useful tool for visualizing different types of data for example, word embeddings, document embeddings or the gene expressions and biological sequences. It just needs an input of 2D tensors and then you can explore your data using provided algorithms. You can also perform nearest neighbours search to find most similar data points to your query point.
#
# # References
#  1. https://grouplens.org/datasets/movielens/
#  2. https://lvdmaaten.github.io/tsne/
